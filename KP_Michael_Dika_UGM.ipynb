# %% [markdown]
# <a href="https://colab.research.google.com/github/pramudyadika/Analisis-Trend-Wisata-Yogya/blob/main/KP_Michael_Dika_UGM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ANALISIS TREND PARIWISATA DI YOGYAKARTA MELALUI MEDIA SOSIAL**

# %% [markdown]
# > Pariwisata merupakan salah satu sektor yang sangat penting dalam perekonomian Indonesia, terutama di Yogyakarta yang terkenal dengan kekayaan alam dan budayanya. Saat ini, media sosial menjadi salah satu sarana utama untuk mempromosikan destinasi pariwisata, termasuk di Yogyakarta. Oleh karena itu, analisis trend pariwisata di Yogyakarta melalui media sosial sangat penting untuk memahami bagaimana wisatawan mengakses informasi tentang destinasi wisata dan bagaimana tren pariwisata di Yogyakarta seiring dengan penggunaan media sosial yang semakin meluas.
#
# > Dalam projek ini, akan dilakukan pengkajian terkait  analisis trend pariwisata di Yogyakarta melalui media sosial dengan menggunakan metode analisis tren dan analisis sentimen. Analisis tren akan digunakan untuk memahami bagaimana tren pariwisata di Yogyakarta pada tahun 2022. Sementara itu, analisis sentimen akan digunakan untuk memahami pandangan wisatawan tentang destinasi wisata di Yogyakarta yang terpapar melalui media sosial.

# %% [markdown]
# ###**1. Melakukan *Import Library***

# %% [markdown]
# > Jalankan kode berikut untuk mengimport library yang akan digunakan dalam proses kali ini

# %%
import gc
import re
import string
import pandas as pd
import numpy as np
import seaborn as sns

import torch
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)
from collections import Counter

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install Sastrawi
# !pip install transformers
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, AutoConfig, TextClassificationPipeline
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 KB 10.3 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 58.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.7)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 24.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 38.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.3 tokenizers-0.13.2 transformers-4.27.4

# %% [markdown]
# ###**2. Melakukan *Load* dataset ke dataframe**

# %%
# Dataframe untuk tweets terkait jogja secara umum
dfjogja = pd.read_csv("https://raw.githubusercontent.com/MichaelHamonangan/Analisis-Trend-Pariwisata-di-Yogyakarta-melalui-Media-Sosial/master/Dataset/jogja_yogyakarta_twt.csv")

# Dataframe untuk tweets terkait wisata jogja
dfjogjawis = pd.read_csv("https://raw.githubusercontent.com/MichaelHamonangan/Analisis-Trend-Pariwisata-di-Yogyakarta-melalui-Media-Sosial/master/Dataset/wisatajogja_twt.csv")

# Dataframe untuk tweets dengan tag untuk tiap-tiap nama wisata yang ada di jogja kota saja
dfwisata = pd.read_csv("https://raw.githubusercontent.com/MichaelHamonangan/Analisis-Trend-Pariwisata-di-Yogyakarta-melalui-Media-Sosial/master/Dataset/twtWisataKota.csv")

# %% [markdown]
# > Melakukan Rename nama kolom ke bentuk standar

# %%
dfjogja = dfjogja.rename(columns={'ID': 'id', 'User': 'user', 'Date Created': 'date_created', 'Number of Likes': 'likes', 'Source of Tweet': 'source', 'Tweet': 'tweet'})
dfjogjawis = dfjogjawis.rename(columns={'ID': 'id', 'User': 'user', 'Date Created': 'date_created', 'Number of Likes': 'likes', 'Source of Tweet': 'source', 'Tweet': 'tweet'})
dfwisata = dfwisata.rename(columns={'ID': 'id', 'User': 'user', 'Date Created': 'date_created', 'Number of Likes': 'likes', 'Source of Tweet': 'source', 'Tweet': 'tweet', 'Tagname': 'tag'})

# %% [markdown]
# > Penyesuaian format untuk *Datetime*

# %%
#Format waktu agar hanya sensitif sampai jam saja
dfjogja['date_created'] = pd.to_datetime(dfjogja['date_created'])
dfjogja['date_time'] = dfjogja['date_created'].apply(lambda x: x.replace(minute=0, second=0))
dfjogja.drop(['date_created'], axis=1, inplace=True)

dfjogjawis['date_created'] = pd.to_datetime(dfjogjawis['date_created'])
dfjogjawis['date_time'] = dfjogjawis['date_created'].apply(lambda x: x.replace(minute=0, second=0))
dfjogjawis.drop(['date_created'], axis=1, inplace=True)

dfwisata['date_created'] = pd.to_datetime(dfwisata['date_created'])
dfwisata['date_time'] = dfwisata['date_created'].apply(lambda x: x.replace(minute=0, second=0))
dfwisata.drop(['date_created'], axis=1, inplace=True)

# %%
dfjogja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451838 entries, 0 to 451837
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         451838 non-null  int64
#  1   user       451838 non-null  object
#  2   likes      451838 non-null  int64
#  3   source     451838 non-null  object
#  4   tweet      451838 non-null  object
#  5   date_time  451838 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(2), object(3)
# memory usage: 20.7+ MB

# %%
dfjogja.tail(10)
# Out:
#             id            user  likes               source  \
# 451828  451828     polresjogja     38      Twitter Web App
# 451829  451829        lokerjog      0       Loker Jogja ID
# 451830  451830  GuruYogyakarta      0            Instagram
# 451831  451831     ahlik3umum_      0      Twitter Web App
# 451832  451832   disporaparjtg      8  Twitter for Android
# 451833  451833  mr_DT_Yanuarsa      0            Instagram
# 451834  451834    Alissa_Butik      0            Instagram
# 451835  451835          KAI121      0             KAI121v2
# 451836  451836       kompascom      0              dlvr.it
# 451837  451837     Kemenag_DIY      0   Twitter for iPhone
#
#                                                     tweet  \
# 451828  Polsek Gedongtengen Tangkap Empat Pelaku Penge...
# 451829  LOKER JOGJA TERBARU: Staff Marketplace di CV. ...
# 451830  Baru saja mengirim foto @ Yogyakarta https://t...
# 451831  Dokumentasi Pembinaan Calon Ahli K3 Umum Serti...
# 451832  Rakor Pokja Program pembangunan pariwisata ter...
# 451833  Kata orang panas.. Kata gue berkah.. @ Titik N...
# 451834  Baru saja mengirim foto @ Special Region of Yo...
# 451835  @jlc147 Selamat pagi Kak. Bila yang dimaksud K...
# 451836  PO Tami Jaya menambah bus baru untuk armadanya...
# 451837  Kabag Tata Usaha Muntolib didampingi Kabid Uru...
#
#                        date_time
# 451828 2022-12-07 03:00:00+00:00
# 451829 2022-12-07 03:00:00+00:00
# 451830 2022-12-07 03:00:00+00:00
# 451831 2022-12-07 03:00:00+00:00
# 451832 2022-12-07 03:00:00+00:00
# 451833 2022-12-07 03:00:00+00:00
# 451834 2022-12-07 03:00:00+00:00
# 451835 2022-12-07 03:00:00+00:00
# 451836 2022-12-07 03:00:00+00:00
# 451837 2022-12-07 03:00:00+00:00

# %%
dfjogjawis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19585 entries, 0 to 19584
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         19585 non-null  int64
#  1   user       19585 non-null  object
#  2   likes      19585 non-null  int64
#  3   source     19585 non-null  object
#  4   tweet      19585 non-null  object
#  5   date_time  19585 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(2), object(3)
# memory usage: 918.2+ KB

# %%
dfjogjawis.tail(10)
# Out:
#           id            user  likes               source  \
# 19575  19575     infobmkgyia      0      Twitter Web App
# 19576  19576  BikinLaparMata      0         twittbot.net
# 19577  19577       wisataapp      4   Twitter for iPhone
# 19578  19578       rkrijuara      6      Twitter Web App
# 19579  19579   fajarposmedia      0              dlvr.it
# 19580  19580      merrie_red      5  Twitter for Android
# 19581  19581   SinergiPapers      0      Twitter Web App
# 19582  19582     infobmkgyia      1      Twitter Web App
# 19583  19583    mekanisasiKP      0      Twitter Web App
# 19584  19584    mitabusjogja      0  Twitter for Android
#
#                                                    tweet  \
# 19575  Berikut kami sampaikan Prakiraan Cuaca Lokasi ...
# 19576  Yogyakarta terkenal dgn wisata kuliner yg mura...
# 19577  Ada berbagai tempat wisata yang bisa Anda kunj...
# 19578  Best 5 Oto: Bertandang ke Toyota xEV Center, @...
# 19579  HeHa Sky View Spot Nongkorong Keren di Jogja: ...
# 19580  @waspkick @seper_sepuluh Sepertinya tidak. Yog...
# 19581  Wisata Yogyakarta yang Selalu Menjadi Tren di ...
# 19582  Berikut kami sampaikan Prakiraan Cuaca Lokasi ...
# 19583  Selain sebagai Kp. Pramuka, Bromonilan juga me...
# 19584  Masih ready ya kak\nMedium Bus Pariwisata untu...
#
#                       date_time
# 19575 2022-12-02 03:00:00+00:00
# 19576 2022-12-02 02:00:00+00:00
# 19577 2022-12-01 14:00:00+00:00
# 19578 2022-12-01 12:00:00+00:00
# 19579 2022-12-01 11:00:00+00:00
# 19580 2022-12-01 06:00:00+00:00
# 19581 2022-12-01 05:00:00+00:00
# 19582 2022-12-01 03:00:00+00:00
# 19583 2022-12-01 01:00:00+00:00
# 19584 2022-12-01 00:00:00+00:00

# %%
dfwisata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35368 entries, 0 to 35367
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         35368 non-null  int64
#  1   user       35368 non-null  object
#  2   likes      35368 non-null  int64
#  3   source     35368 non-null  object
#  4   tweet      35368 non-null  object
#  5   tag        35368 non-null  object
#  6   date_time  35368 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(2), object(4)
# memory usage: 1.9+ MB

# %%
dfwisata.tail(10)
# Out:
#           id           user  likes               source  \
# 35358  35359       rhdinsky      0  Twitter for Android
# 35359  35360    louisdesanc      0  Twitter for Android
# 35360  35361    waterainluv      5  Twitter for Android
# 35361  35362          NzulR      0      Twitter Web App
# 35362  35363       dinxxx8h      0      Twitter Web App
# 35363  35364        sorr_yy      0  Twitter for Android
# 35364  35365   schwittlick_      1      Twitter Web App
# 35365  35366    sasukemikir      0      Twitter Web App
# 35366  35367       arizalp_      0   Twitter for iPhone
# 35367  35368  tershanjung13      4  Twitter for Android
#
#                                                    tweet     tag  \
# 35358   @hasseennnn yg samping has arah ke tempat artjog  Artjog
# 35359  Bagus karyanya kak g4lih di artjog kmaren. Kok...  Artjog
# 35360  @Yupiboli @convomf Ini karyanya bisa dipajang ...  Artjog
# 35361                       @artjog 2022 ada lagi gak ya  Artjog
# 35362        @ngalamfess Artjog nder tapi di jogja sih 😅  Artjog
# 35363  @Akhlis_M @itskinda_dita @wikan_bagas @sinemas...  Artjog
# 35364  @claracxw @nft_asia Maybe you know @ignatianil...  Artjog
# 35365  tbtb kangen ke jogja naik kereta terus ke artj...  Artjog
# 35366  @chocolat0zze @sinemasisifus @salsaistya Ayo k...  Artjog
# 35367  cok iling pas nng artjog koncoe sigit ngongkon...  Artjog
#
#                       date_time
# 35358 2022-01-11 05:00:00+00:00
# 35359 2022-01-10 15:00:00+00:00
# 35360 2022-01-08 05:00:00+00:00
# 35361 2022-01-08 01:00:00+00:00
# 35362 2022-01-07 13:00:00+00:00
# 35363 2022-01-05 13:00:00+00:00
# 35364 2022-01-03 09:00:00+00:00
# 35365 2022-01-01 13:00:00+00:00
# 35366 2022-01-01 11:00:00+00:00
# 35367 2022-01-01 09:00:00+00:00

# %% [markdown]
# ###**3. Dataframe *Preprocessing***

# %%
print(dfjogja.shape)
print(dfjogjawis.shape)
print(dfwisata.shape)
# Out:
# (451838, 6)
# (19585, 6)
# (35368, 7)

# %% [markdown]
# > **Row Preprocessing**

# %% [markdown]
# *   Menghapus Baris yang bersifat duplikat berdasar atribut user, tweet, and date.

# %%
# Membuat kolom *dummy* yaitu date agar duplikasi yang dihapus adalah tweet yang sama yang dikirim oleh user yang sama dalam satu hari

dfjogja['date'] = pd.to_datetime(dfjogja['date_time']).dt.date
dfjogjawis['date'] = pd.to_datetime(dfjogjawis['date_time']).dt.date
dfwisata['date'] = pd.to_datetime(dfwisata['date_time']).dt.date

# %%
print("number of duplicate rows dfjogja: ", dfjogja[dfjogja.duplicated(['user', 'tweet','date'])].shape)
dfjogja = dfjogja.drop_duplicates(['user', 'tweet','date'])

print("number of duplicate rows dfjogjawis: ", dfjogjawis[dfjogjawis.duplicated(['user', 'tweet','date'])].shape)
dfjojgawis = dfjogjawis.drop_duplicates(['user', 'tweet','date'])

print("number of duplicate rows dfwisata: ", dfwisata[dfwisata.duplicated(['user', 'tweet','date'])].shape)
dfwisata = dfwisata.drop_duplicates(['user', 'tweet','date'])

# Menghapus lagi kolom date yang dipakai sebagai dummy atribut
dfjogja.drop(['date'], axis=1, inplace=True)
dfjogjawis.drop(['date'], axis=1, inplace=True)
dfwisata.drop(['date'], axis=1, inplace=True)
# Out:
# number of duplicate rows dfjogja:  (13292, 7)
# number of duplicate rows dfjogjawis:  (2620, 7)
# number of duplicate rows dfwisata:  (1792, 8)

# %% [markdown]
# *   Menghapus baris yang memiliki nilai Null (jika ada)

# %%
dfjogja.isnull().sum()
# Out:
# id           0
# user         0
# likes        0
# source       0
# tweet        0
# date_time    0
# dtype: int64

# %%
dfjogjawis.isnull().sum()
# Out:
# id           0
# user         0
# likes        0
# source       0
# tweet        0
# date_time    0
# dtype: int64

# %%
dfwisata.isnull().sum()
# Out:
# id           0
# user         0
# likes        0
# source       0
# tweet        0
# tag          0
# date_time    0
# dtype: int64

# %% [markdown]
# > **Column Preprocessing**
#
#
# *   Menghapus atribut **user** untuk semua dataframe karena identitas tidak mempengaruhi hasil

# %%
dfjogja.drop(['user'], axis=1, inplace=True)
dfjogjawis.drop(['user'], axis=1, inplace=True)
dfwisata.drop(['user'], axis=1, inplace=True)

# %%
dfjogja.tail(10)
# Out:
#             id  likes               source  \
# 451828  451828     38      Twitter Web App
# 451829  451829      0       Loker Jogja ID
# 451830  451830      0            Instagram
# 451831  451831      0      Twitter Web App
# 451832  451832      8  Twitter for Android
# 451833  451833      0            Instagram
# 451834  451834      0            Instagram
# 451835  451835      0             KAI121v2
# 451836  451836      0              dlvr.it
# 451837  451837      0   Twitter for iPhone
#
#                                                     tweet  \
# 451828  Polsek Gedongtengen Tangkap Empat Pelaku Penge...
# 451829  LOKER JOGJA TERBARU: Staff Marketplace di CV. ...
# 451830  Baru saja mengirim foto @ Yogyakarta https://t...
# 451831  Dokumentasi Pembinaan Calon Ahli K3 Umum Serti...
# 451832  Rakor Pokja Program pembangunan pariwisata ter...
# 451833  Kata orang panas.. Kata gue berkah.. @ Titik N...
# 451834  Baru saja mengirim foto @ Special Region of Yo...
# 451835  @jlc147 Selamat pagi Kak. Bila yang dimaksud K...
# 451836  PO Tami Jaya menambah bus baru untuk armadanya...
# 451837  Kabag Tata Usaha Muntolib didampingi Kabid Uru...
#
#                        date_time
# 451828 2022-12-07 03:00:00+00:00
# 451829 2022-12-07 03:00:00+00:00
# 451830 2022-12-07 03:00:00+00:00
# 451831 2022-12-07 03:00:00+00:00
# 451832 2022-12-07 03:00:00+00:00
# 451833 2022-12-07 03:00:00+00:00
# 451834 2022-12-07 03:00:00+00:00
# 451835 2022-12-07 03:00:00+00:00
# 451836 2022-12-07 03:00:00+00:00
# 451837 2022-12-07 03:00:00+00:00

# %%
dfjogjawis.tail(10)
# Out:
#           id  likes               source  \
# 19575  19575      0      Twitter Web App
# 19576  19576      0         twittbot.net
# 19577  19577      4   Twitter for iPhone
# 19578  19578      6      Twitter Web App
# 19579  19579      0              dlvr.it
# 19580  19580      5  Twitter for Android
# 19581  19581      0      Twitter Web App
# 19582  19582      1      Twitter Web App
# 19583  19583      0      Twitter Web App
# 19584  19584      0  Twitter for Android
#
#                                                    tweet  \
# 19575  Berikut kami sampaikan Prakiraan Cuaca Lokasi ...
# 19576  Yogyakarta terkenal dgn wisata kuliner yg mura...
# 19577  Ada berbagai tempat wisata yang bisa Anda kunj...
# 19578  Best 5 Oto: Bertandang ke Toyota xEV Center, @...
# 19579  HeHa Sky View Spot Nongkorong Keren di Jogja: ...
# 19580  @waspkick @seper_sepuluh Sepertinya tidak. Yog...
# 19581  Wisata Yogyakarta yang Selalu Menjadi Tren di ...
# 19582  Berikut kami sampaikan Prakiraan Cuaca Lokasi ...
# 19583  Selain sebagai Kp. Pramuka, Bromonilan juga me...
# 19584  Masih ready ya kak\nMedium Bus Pariwisata untu...
#
#                       date_time
# 19575 2022-12-02 03:00:00+00:00
# 19576 2022-12-02 02:00:00+00:00
# 19577 2022-12-01 14:00:00+00:00
# 19578 2022-12-01 12:00:00+00:00
# 19579 2022-12-01 11:00:00+00:00
# 19580 2022-12-01 06:00:00+00:00
# 19581 2022-12-01 05:00:00+00:00
# 19582 2022-12-01 03:00:00+00:00
# 19583 2022-12-01 01:00:00+00:00
# 19584 2022-12-01 00:00:00+00:00

# %%
dfwisata.tail(10)
# Out:
#           id  likes               source  \
# 35358  35359      0  Twitter for Android
# 35359  35360      0  Twitter for Android
# 35360  35361      5  Twitter for Android
# 35361  35362      0      Twitter Web App
# 35362  35363      0      Twitter Web App
# 35363  35364      0  Twitter for Android
# 35364  35365      1      Twitter Web App
# 35365  35366      0      Twitter Web App
# 35366  35367      0   Twitter for iPhone
# 35367  35368      4  Twitter for Android
#
#                                                    tweet     tag  \
# 35358   @hasseennnn yg samping has arah ke tempat artjog  Artjog
# 35359  Bagus karyanya kak g4lih di artjog kmaren. Kok...  Artjog
# 35360  @Yupiboli @convomf Ini karyanya bisa dipajang ...  Artjog
# 35361                       @artjog 2022 ada lagi gak ya  Artjog
# 35362        @ngalamfess Artjog nder tapi di jogja sih 😅  Artjog
# 35363  @Akhlis_M @itskinda_dita @wikan_bagas @sinemas...  Artjog
# 35364  @claracxw @nft_asia Maybe you know @ignatianil...  Artjog
# 35365  tbtb kangen ke jogja naik kereta terus ke artj...  Artjog
# 35366  @chocolat0zze @sinemasisifus @salsaistya Ayo k...  Artjog
# 35367  cok iling pas nng artjog koncoe sigit ngongkon...  Artjog
#
#                       date_time
# 35358 2022-01-11 05:00:00+00:00
# 35359 2022-01-10 15:00:00+00:00
# 35360 2022-01-08 05:00:00+00:00
# 35361 2022-01-08 01:00:00+00:00
# 35362 2022-01-07 13:00:00+00:00
# 35363 2022-01-05 13:00:00+00:00
# 35364 2022-01-03 09:00:00+00:00
# 35365 2022-01-01 13:00:00+00:00
# 35366 2022-01-01 11:00:00+00:00
# 35367 2022-01-01 09:00:00+00:00

# %%
print(dfjogja.shape)
print(dfjogjawis.shape)
print(dfwisata.shape)
# Out:
# (438546, 5)
# (19585, 5)
# (33576, 6)

# %% [markdown]
# ###**4. Case Folding**

# %% [markdown]
# > Akan dilakukan cleaning terhadap data tweets yang meliputi :
#
#
#
# *   Membuat teks dalam huruf kecil semua (mengganti huruf kapital)
# *   Menghilangkan teks yang didalamkurungi
# *   Menghilangkan teks yang berupa link
# *   Menghilangkan tanda baca
# *   Menghilangkan kata yang mengandung angka

# %%
def clean_text(text):

    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
dfjogja['tweet'] = dfjogja['tweet'].apply(lambda x:clean_text(x))
dfjogjawis['tweet'] = dfjogjawis['tweet'].apply(lambda x:clean_text(x))
dfwisata['tweet'] = dfwisata['tweet'].apply(lambda x:clean_text(x))

# %% [markdown]
# > **Cleaning Stopwords**

# %%
# Melakukan tokenisasi tiap kata untuk tweet dan menyimpannya ke kolom baru yang kita namakan temp_list

dfjogja['temp_list'] = dfjogja['tweet'].apply(lambda x:str(x).split())
dfjogjawis['temp_list'] = dfjogjawis['tweet'].apply(lambda x:str(x).split())
dfwisata['temp_list'] = dfwisata['tweet'].apply(lambda x:str(x).split())

# %% [markdown]
# Contoh untuk most common word pada dataframe jogjawis

# %%
print("Jogjawis".center(24," "))
top = Counter([item for sublist in dfjogjawis['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
#         Jogjawis
# <style type="text/css">
# #T_0bdf2_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0bdf2_row1_col1 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_0bdf2_row2_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_0bdf2_row3_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_0bdf2_row4_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_0bdf2_row5_col1, #T_0bdf2_row6_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_0bdf2_row7_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_0bdf2_row8_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_0bdf2_row9_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_0bdf2_row10_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_0bdf2_row11_col1, #T_0bdf2_row12_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_0bdf2_row13_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_0bdf2_row14_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_0bdf2_row15_col1, #T_0bdf2_row16_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_0bdf2_row17_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_0bdf2_row18_col1, #T_0bdf2_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_0bdf2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bdf2_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_0bdf2_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bdf2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0bdf2_row0_col0" class="data row0 col0" >wisata</td>
#       <td id="T_0bdf2_row0_col1" class="data row0 col1" >20283</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0bdf2_row1_col0" class="data row1 col0" >jogja</td>
#       <td id="T_0bdf2_row1_col1" class="data row1 col1" >16343</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0bdf2_row2_col0" class="data row2 col0" >di</td>
#       <td id="T_0bdf2_row2_col1" class="data row2 col1" >8852</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0bdf2_row3_col0" class="data row3 col0" >yogyakarta</td>
#       <td id="T_0bdf2_row3_col1" class="data row3 col1" >4187</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0bdf2_row4_col0" class="data row4 col0" >dan</td>
#       <td id="T_0bdf2_row4_col1" class="data row4 col1" >3932</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0bdf2_row5_col0" class="data row5 col0" >yang</td>
#       <td id="T_0bdf2_row5_col1" class="data row5 col1" >3482</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0bdf2_row6_col0" class="data row6 col0" >tempat</td>
#       <td id="T_0bdf2_row6_col1" class="data row6 col1" >3425</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0bdf2_row7_col0" class="data row7 col0" >ke</td>
#       <td id="T_0bdf2_row7_col1" class="data row7 col1" >3367</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0bdf2_row8_col0" class="data row8 col0" >traveling</td>
#       <td id="T_0bdf2_row8_col1" class="data row8 col1" >3212</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0bdf2_row9_col0" class="data row9 col0" >alam</td>
#       <td id="T_0bdf2_row9_col1" class="data row9 col1" >3045</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0bdf2_row10_col0" class="data row10 col0" >ini</td>
#       <td id="T_0bdf2_row10_col1" class="data row10 col1" >2635</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0bdf2_row11_col0" class="data row11 col0" >guide</td>
#       <td id="T_0bdf2_row11_col1" class="data row11 col1" >2582</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0bdf2_row12_col0" class="data row12 col0" >jogjacitytour</td>
#       <td id="T_0bdf2_row12_col1" class="data row12 col1" >2555</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0bdf2_row13_col0" class="data row13 col0" >yg</td>
#       <td id="T_0bdf2_row13_col1" class="data row13 col1" >1949</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0bdf2_row14_col0" class="data row14 col0" >jelajah</td>
#       <td id="T_0bdf2_row14_col1" class="data row14 col1" >1870</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0bdf2_row15_col0" class="data row15 col0" >untuk</td>
#       <td id="T_0bdf2_row15_col1" class="data row15 col1" >1778</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0bdf2_row16_col0" class="data row16 col0" >dari</td>
#       <td id="T_0bdf2_row16_col1" class="data row16 col1" >1742</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0bdf2_row17_col0" class="data row17 col0" >curug</td>
#       <td id="T_0bdf2_row17_col1" class="data row17 col1" >1723</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0bdf2_row18_col0" class="data row18 col0" >diy</td>
#       <td id="T_0bdf2_row18_col1" class="data row18 col1" >1564</td>
#     </tr>
#     <tr>
#       <th id="T_0bdf2_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0bdf2_row19_col0" class="data row19 col0" >kota</td>
#       <td id="T_0bdf2_row19_col1" class="data row19 col1" >1507</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Kata-kata diatas masih dipenuhi dengan kata yang disebut 'stopwords', yaitu kata yang seharusnya diabaikan dalam pemrosesan bahasa alami karena tidak memiliki nilai informasi apapun terhadap sentimen analisis kita nantinya. Contohnya adalah di, dan, yang, ini, dst

# %%
indonesian_stopwords = stopwords.words('indonesian')
indonesian_stopwords.append('yg')                                           #karena yg adalah tulisan gaul yang artinya yang
print(len(indonesian_stopwords), "stopwords:", indonesian_stopwords)

def remove_stopword(x):
    return [y for y in x if y not in indonesian_stopwords]
# Out:
# 759 stopwords: ['ada', 'adalah', 'adanya', 'adapun', 'agak', 'agaknya', 'agar', 'akan', 'akankah', 'akhir', 'akhiri', 'akhirnya', 'aku', 'akulah', 'amat', 'amatlah', 'anda', 'andalah', 'antar', 'antara', 'antaranya', 'apa', 'apaan', 'apabila', 'apakah', 'apalagi', 'apatah', 'artinya', 'asal', 'asalkan', 'atas', 'atau', 'ataukah', 'ataupun', 'awal', 'awalnya', 'bagai', 'bagaikan', 'bagaimana', 'bagaimanakah', 'bagaimanapun', 'bagi', 'bagian', 'bahkan', 'bahwa', 'bahwasanya', 'baik', 'bakal', 'bakalan', 'balik', 'banyak', 'bapak', 'baru', 'bawah', 'beberapa', 'begini', 'beginian', 'beginikah', 'beginilah', 'begitu', 'begitukah', 'begitulah', 'begitupun', 'bekerja', 'belakang', 'belakangan', 'belum', 'belumlah', 'benar', 'benarkah', 'benarlah', 'berada', 'berakhir', 'berakhirlah', 'berakhirnya', 'berapa', 'berapakah', 'berapalah', 'berapapun', 'berarti', 'berawal', 'berbagai', 'berdatangan', 'beri', 'berikan', 'berikut', 'berikutnya', 'berjumlah', 'berkali-kali', 'berkata', 'berkehendak', 'berkeinginan', 'berkenaan', 'berlainan', 'berlalu', 'berlangsung', 'berlebihan', 'bermacam', 'bermacam-macam', 'bermaksud', 'bermula', 'bersama', 'bersama-sama', 'bersiap', 'bersiap-siap', 'bertanya', 'bertanya-tanya', 'berturut', 'berturut-turut', 'bertutur', 'berujar', 'berupa', 'besar', 'betul', 'betulkah', 'biasa', 'biasanya', 'bila', 'bilakah', 'bisa', 'bisakah', 'boleh', 'bolehkah', 'bolehlah', 'buat', 'bukan', 'bukankah', 'bukanlah', 'bukannya', 'bulan', 'bung', 'cara', 'caranya', 'cukup', 'cukupkah', 'cukuplah', 'cuma', 'dahulu', 'dalam', 'dan', 'dapat', 'dari', 'daripada', 'datang', 'dekat', 'demi', 'demikian', 'demikianlah', 'dengan', 'depan', 'di', 'dia', 'diakhiri', 'diakhirinya', 'dialah', 'diantara', 'diantaranya', 'diberi', 'diberikan', 'diberikannya', 'dibuat', 'dibuatnya', 'didapat', 'didatangkan', 'digunakan', 'diibaratkan', 'diibaratkannya', 'diingat', 'diingatkan', 'diinginkan', 'dijawab', 'dijelaskan', 'dijelaskannya', 'dikarenakan', 'dikatakan', 'dikatakannya', 'dikerjakan', 'diketahui', 'diketahuinya', 'dikira', 'dilakukan', 'dilalui', 'dilihat', 'dimaksud', 'dimaksudkan', 'dimaksudkannya', 'dimaksudnya', 'diminta', 'dimintai', 'dimisalkan', 'dimulai', 'dimulailah', 'dimulainya', 'dimungkinkan', 'dini', 'dipastikan', 'diperbuat', 'diperbuatnya', 'dipergunakan', 'diperkirakan', 'diperlihatkan', 'diperlukan', 'diperlukannya', 'dipersoalkan', 'dipertanyakan', 'dipunyai', 'diri', 'dirinya', 'disampaikan', 'disebut', 'disebutkan', 'disebutkannya', 'disini', 'disinilah', 'ditambahkan', 'ditandaskan', 'ditanya', 'ditanyai', 'ditanyakan', 'ditegaskan', 'ditujukan', 'ditunjuk', 'ditunjuki', 'ditunjukkan', 'ditunjukkannya', 'ditunjuknya', 'dituturkan', 'dituturkannya', 'diucapkan', 'diucapkannya', 'diungkapkan', 'dong', 'dua', 'dulu', 'empat', 'enggak', 'enggaknya', 'entah', 'entahlah', 'guna', 'gunakan', 'hal', 'hampir', 'hanya', 'hanyalah', 'hari', 'harus', 'haruslah', 'harusnya', 'hendak', 'hendaklah', 'hendaknya', 'hingga', 'ia', 'ialah', 'ibarat', 'ibaratkan', 'ibaratnya', 'ibu', 'ikut', 'ingat', 'ingat-ingat', 'ingin', 'inginkah', 'inginkan', 'ini', 'inikah', 'inilah', 'itu', 'itukah', 'itulah', 'jadi', 'jadilah', 'jadinya', 'jangan', 'jangankan', 'janganlah', 'jauh', 'jawab', 'jawaban', 'jawabnya', 'jelas', 'jelaskan', 'jelaslah', 'jelasnya', 'jika', 'jikalau', 'juga', 'jumlah', 'jumlahnya', 'justru', 'kala', 'kalau', 'kalaulah', 'kalaupun', 'kalian', 'kami', 'kamilah', 'kamu', 'kamulah', 'kan', 'kapan', 'kapankah', 'kapanpun', 'karena', 'karenanya', 'kasus', 'kata', 'katakan', 'katakanlah', 'katanya', 'ke', 'keadaan', 'kebetulan', 'kecil', 'kedua', 'keduanya', 'keinginan', 'kelamaan', 'kelihatan', 'kelihatannya', 'kelima', 'keluar', 'kembali', 'kemudian', 'kemungkinan', 'kemungkinannya', 'kenapa', 'kepada', 'kepadanya', 'kesampaian', 'keseluruhan', 'keseluruhannya', 'keterlaluan', 'ketika', 'khususnya', 'kini', 'kinilah', 'kira', 'kira-kira', 'kiranya', 'kita', 'kitalah', 'kok', 'kurang', 'lagi', 'lagian', 'lah', 'lain', 'l ...

# %%
dfjogja['temp_list'] = dfjogja['temp_list'].apply(lambda x:remove_stopword(x))
dfjogjawis['temp_list'] = dfjogjawis['temp_list'].apply(lambda x:remove_stopword(x))
dfwisata['temp_list'] = dfwisata['temp_list'].apply(lambda x:remove_stopword(x))

# %% [markdown]
# * Hasil most common word word untuk ketiga dataframe

# %%
print("Dataframe Jogja".center(24," "))
top = Counter([item for sublist in dfjogja['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Greens')
# Out:
#     Dataframe Jogja
# <style type="text/css">
# #T_4eaef_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_4eaef_row1_col1 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_4eaef_row2_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_4eaef_row3_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_4eaef_row4_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_4eaef_row5_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_4eaef_row6_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_4eaef_row7_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_4eaef_row8_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_4eaef_row9_col1, #T_4eaef_row10_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_4eaef_row11_col1, #T_4eaef_row12_col1, #T_4eaef_row13_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_4eaef_row14_col1, #T_4eaef_row15_col1, #T_4eaef_row16_col1, #T_4eaef_row17_col1, #T_4eaef_row18_col1, #T_4eaef_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_4eaef" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4eaef_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_4eaef_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4eaef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4eaef_row0_col0" class="data row0 col0" >jogja</td>
#       <td id="T_4eaef_row0_col1" class="data row0 col1" >277907</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4eaef_row1_col0" class="data row1 col0" >yogyakarta</td>
#       <td id="T_4eaef_row1_col1" class="data row1 col1" >132520</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4eaef_row2_col0" class="data row2 col0" >dom</td>
#       <td id="T_4eaef_row2_col1" class="data row2 col1" >33080</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4eaef_row3_col0" class="data row3 col0" >ya</td>
#       <td id="T_4eaef_row3_col1" class="data row3 col1" >25425</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4eaef_row4_col0" class="data row4 col0" >loker</td>
#       <td id="T_4eaef_row4_col1" class="data row4 col1" >20815</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4eaef_row5_col0" class="data row5 col0" >istimewa</td>
#       <td id="T_4eaef_row5_col1" class="data row5 col1" >20446</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4eaef_row6_col0" class="data row6 col0" >aja</td>
#       <td id="T_4eaef_row6_col1" class="data row6 col1" >18823</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4eaef_row7_col0" class="data row7 col0" >ga</td>
#       <td id="T_4eaef_row7_col1" class="data row7 col1" >18215</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4eaef_row8_col0" class="data row8 col0" >daerah</td>
#       <td id="T_4eaef_row8_col1" class="data row8 col1" >16677</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4eaef_row9_col0" class="data row9 col0" >kota</td>
#       <td id="T_4eaef_row9_col1" class="data row9 col1" >14915</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4eaef_row10_col0" class="data row10 col0" >kalo</td>
#       <td id="T_4eaef_row10_col1" class="data row10 col1" >14575</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4eaef_row11_col0" class="data row11 col0" >to</td>
#       <td id="T_4eaef_row11_col1" class="data row11 col1" >12292</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4eaef_row12_col0" class="data row12 col0" >indonesia</td>
#       <td id="T_4eaef_row12_col1" class="data row12 col1" >12227</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4eaef_row13_col0" class="data row13 col0" >amp</td>
#       <td id="T_4eaef_row13_col1" class="data row13 col1" >11808</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4eaef_row14_col0" class="data row14 col0" >terbaru</td>
#       <td id="T_4eaef_row14_col1" class="data row14 col1" >11026</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4eaef_row15_col0" class="data row15 col0" >masyarakat</td>
#       <td id="T_4eaef_row15_col1" class="data row15 col1" >10965</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4eaef_row16_col0" class="data row16 col0" >solo</td>
#       <td id="T_4eaef_row16_col1" class="data row16 col1" >10364</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4eaef_row17_col0" class="data row17 col0" >udah</td>
#       <td id="T_4eaef_row17_col1" class="data row17 col1" >10171</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4eaef_row18_col0" class="data row18 col0" >kak</td>
#       <td id="T_4eaef_row18_col1" class="data row18 col1" >9986</td>
#     </tr>
#     <tr>
#       <th id="T_4eaef_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4eaef_row19_col0" class="data row19 col0" >lowongankerjajogja</td>
#       <td id="T_4eaef_row19_col1" class="data row19 col1" >9984</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfjogja.tail(5)
# Out:
#             id  likes              source  \
# 451833  451833      0           Instagram
# 451834  451834      0           Instagram
# 451835  451835      0            KAI121v2
# 451836  451836      0             dlvr.it
# 451837  451837      0  Twitter for iPhone
#
#                                                     tweet  \
# 451833  kata orang panas kata gue berkah  titik nol km...
# 451834  baru saja mengirim foto  special region of yog...
# 451835   selamat pagi kak bila yang dimaksud kakak sud...
# 451836  po tami jaya menambah bus baru untuk armadanya...
# 451837  kabag tata usaha muntolib didampingi kabid uru...
#
#                        date_time  \
# 451833 2022-12-07 03:00:00+00:00
# 451834 2022-12-07 03:00:00+00:00
# 451835 2022-12-07 03:00:00+00:00
# 451836 2022-12-07 03:00:00+00:00
# 451837 2022-12-07 03:00:00+00:00
#
#                                                 temp_list
# 451833  [orang, panas, gue, berkah, titik, nol, km, yo...
# 451834  [mengirim, foto, special, region, of, yogyakarta]
# 451835  [selamat, pagi, kak, kakak, memiliki, tiket, k...
# 451836  [po, tami, jaya, menambah, bus, armadanya, mel...
# 451837  [kabag, tata, usaha, muntolib, didampingi, kab...

# %%
print("Dataframe Jogjawis".center(24," "))
top = Counter([item for sublist in dfjogjawis['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
#    Dataframe Jogjawis
# <style type="text/css">
# #T_2def0_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2def0_row1_col1 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_2def0_row2_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_2def0_row3_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_2def0_row4_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_2def0_row5_col1, #T_2def0_row6_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_2def0_row7_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_2def0_row8_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_2def0_row9_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_2def0_row10_col1, #T_2def0_row11_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_2def0_row12_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_2def0_row13_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_2def0_row14_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_2def0_row15_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_2def0_row16_col1, #T_2def0_row17_col1, #T_2def0_row18_col1, #T_2def0_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_2def0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2def0_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_2def0_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2def0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2def0_row0_col0" class="data row0 col0" >wisata</td>
#       <td id="T_2def0_row0_col1" class="data row0 col1" >20283</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2def0_row1_col0" class="data row1 col0" >jogja</td>
#       <td id="T_2def0_row1_col1" class="data row1 col1" >16343</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2def0_row2_col0" class="data row2 col0" >yogyakarta</td>
#       <td id="T_2def0_row2_col1" class="data row2 col1" >4187</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2def0_row3_col0" class="data row3 col0" >traveling</td>
#       <td id="T_2def0_row3_col1" class="data row3 col1" >3212</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2def0_row4_col0" class="data row4 col0" >alam</td>
#       <td id="T_2def0_row4_col1" class="data row4 col1" >3045</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2def0_row5_col0" class="data row5 col0" >guide</td>
#       <td id="T_2def0_row5_col1" class="data row5 col1" >2582</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2def0_row6_col0" class="data row6 col0" >jogjacitytour</td>
#       <td id="T_2def0_row6_col1" class="data row6 col1" >2555</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2def0_row7_col0" class="data row7 col0" >jelajah</td>
#       <td id="T_2def0_row7_col1" class="data row7 col1" >1870</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2def0_row8_col0" class="data row8 col0" >curug</td>
#       <td id="T_2def0_row8_col1" class="data row8 col1" >1723</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2def0_row9_col0" class="data row9 col0" >diy</td>
#       <td id="T_2def0_row9_col1" class="data row9 col1" >1564</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2def0_row10_col0" class="data row10 col0" >kota</td>
#       <td id="T_2def0_row10_col1" class="data row10 col1" >1507</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2def0_row11_col0" class="data row11 col0" >liburan</td>
#       <td id="T_2def0_row11_col1" class="data row11 col1" >1464</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2def0_row12_col0" class="data row12 col0" >desa</td>
#       <td id="T_2def0_row12_col1" class="data row12 col1" >1445</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2def0_row13_col0" class="data row13 col0" >merapi</td>
#       <td id="T_2def0_row13_col1" class="data row13 col1" >1254</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2def0_row14_col0" class="data row14 col0" >pantai</td>
#       <td id="T_2def0_row14_col1" class="data row14 col1" >1161</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2def0_row15_col0" class="data row15 col0" >yuk</td>
#       <td id="T_2def0_row15_col1" class="data row15 col1" >1080</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2def0_row16_col0" class="data row16 col0" >destinasi</td>
#       <td id="T_2def0_row16_col1" class="data row16 col1" >1073</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2def0_row17_col0" class="data row17 col0" >pagi</td>
#       <td id="T_2def0_row17_col1" class="data row17 col1" >1027</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2def0_row18_col0" class="data row18 col0" >sleman</td>
#       <td id="T_2def0_row18_col1" class="data row18 col1" >1005</td>
#     </tr>
#     <tr>
#       <th id="T_2def0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2def0_row19_col0" class="data row19 col0" >wisatajogja</td>
#       <td id="T_2def0_row19_col1" class="data row19 col1" >1002</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfjogjawis.tail(5)
# Out:
#           id  likes               source  \
# 19580  19580      5  Twitter for Android
# 19581  19581      0      Twitter Web App
# 19582  19582      1      Twitter Web App
# 19583  19583      0      Twitter Web App
# 19584  19584      0  Twitter for Android
#
#                                                    tweet  \
# 19580  waspkick sepersepuluh sepertinya tidak yogyaka...
# 19581  wisata yogyakarta yang selalu menjadi tren di ...
# 19582  berikut kami sampaikan prakiraan cuaca lokasi ...
# 19583  selain sebagai kp pramuka bromonilan juga meru...
# 19584  masih ready ya kakmedium bus pariwisata untuk ...
#
#                       date_time  \
# 19580 2022-12-01 06:00:00+00:00
# 19581 2022-12-01 05:00:00+00:00
# 19582 2022-12-01 03:00:00+00:00
# 19583 2022-12-01 01:00:00+00:00
# 19584 2022-12-01 00:00:00+00:00
#
#                                                temp_list
# 19580  [waspkick, sepersepuluh, yogyakarta, msh, bert...
# 19581    [wisata, yogyakarta, tren, kalangan, wisatawan]
# 19582  [prakiraan, cuaca, lokasi, wisata, lereng, mer...
# 19583  [kp, pramuka, bromonilan, salah, desa, wisata,...
# 19584  [ready, ya, kakmedium, bus, pariwisata, keperl...

# %%
print("Dataframe Wisata".center(24," "))
top = Counter([item for sublist in dfwisata['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Reds')
# Out:
#     Dataframe Wisata
# <style type="text/css">
# #T_a1fb0_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_a1fb0_row1_col1 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_a1fb0_row2_col1 {
#   background-color: #fc8060;
#   color: #f1f1f1;
# }
# #T_a1fb0_row3_col1 {
#   background-color: #fc8d6d;
#   color: #f1f1f1;
# }
# #T_a1fb0_row4_col1 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_a1fb0_row5_col1, #T_a1fb0_row6_col1 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_a1fb0_row7_col1 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_a1fb0_row8_col1 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_a1fb0_row9_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_a1fb0_row10_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_a1fb0_row11_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_a1fb0_row12_col1, #T_a1fb0_row13_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_a1fb0_row14_col1, #T_a1fb0_row15_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_a1fb0_row16_col1, #T_a1fb0_row17_col1 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_a1fb0_row18_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_a1fb0_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_a1fb0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1fb0_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_a1fb0_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1fb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1fb0_row0_col0" class="data row0 col0" >malioboro</td>
#       <td id="T_a1fb0_row0_col1" class="data row0 col1" >9976</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1fb0_row1_col0" class="data row1 col0" >tamansari</td>
#       <td id="T_a1fb0_row1_col1" class="data row1 col1" >5530</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1fb0_row2_col0" class="data row2 col0" >artjog</td>
#       <td id="T_a1fb0_row2_col1" class="data row2 col1" >4977</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1fb0_row3_col0" class="data row3 col0" >taman</td>
#       <td id="T_a1fb0_row3_col1" class="data row3 col1" >4623</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1fb0_row4_col0" class="data row4 col0" >sari</td>
#       <td id="T_a1fb0_row4_col1" class="data row4 col1" >4199</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a1fb0_row5_col0" class="data row5 col0" >pasar</td>
#       <td id="T_a1fb0_row5_col1" class="data row5 col1" >3868</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a1fb0_row6_col0" class="data row6 col0" >jogja</td>
#       <td id="T_a1fb0_row6_col1" class="data row6 col1" >3859</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a1fb0_row7_col0" class="data row7 col0" >kembang</td>
#       <td id="T_a1fb0_row7_col1" class="data row7 col1" >3292</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a1fb0_row8_col0" class="data row8 col0" >museum</td>
#       <td id="T_a1fb0_row8_col1" class="data row8 col1" >2456</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a1fb0_row9_col0" class="data row9 col0" >jalan</td>
#       <td id="T_a1fb0_row9_col1" class="data row9 col1" >2411</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a1fb0_row10_col0" class="data row10 col0" >yogyakarta</td>
#       <td id="T_a1fb0_row10_col1" class="data row10 col1" >2051</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a1fb0_row11_col0" class="data row11 col0" >ya</td>
#       <td id="T_a1fb0_row11_col1" class="data row11 col1" >1958</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a1fb0_row12_col0" class="data row12 col0" >jakarta</td>
#       <td id="T_a1fb0_row12_col1" class="data row12 col1" >1556</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a1fb0_row13_col0" class="data row13 col0" >ga</td>
#       <td id="T_a1fb0_row13_col1" class="data row13 col1" >1536</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a1fb0_row14_col0" class="data row14 col0" >gembira</td>
#       <td id="T_a1fb0_row14_col1" class="data row14 col1" >1383</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a1fb0_row15_col0" class="data row15 col0" >kalo</td>
#       <td id="T_a1fb0_row15_col1" class="data row15 col1" >1379</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a1fb0_row16_col0" class="data row16 col0" >loka</td>
#       <td id="T_a1fb0_row16_col1" class="data row16 col1" >1312</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a1fb0_row17_col0" class="data row17 col0" >aja</td>
#       <td id="T_a1fb0_row17_col1" class="data row17 col1" >1295</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a1fb0_row18_col0" class="data row18 col0" >barat</td>
#       <td id="T_a1fb0_row18_col1" class="data row18 col1" >1271</td>
#     </tr>
#     <tr>
#       <th id="T_a1fb0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a1fb0_row19_col0" class="data row19 col0" >kota</td>
#       <td id="T_a1fb0_row19_col1" class="data row19 col1" >1153</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfwisata.tail(5)
# Out:
#           id  likes               source  \
# 35363  35364      0  Twitter for Android
# 35364  35365      1      Twitter Web App
# 35365  35366      0      Twitter Web App
# 35366  35367      0   Twitter for iPhone
# 35367  35368      4  Twitter for Android
#
#                                                    tweet     tag  \
# 35363  akhlism itskindadita wikanbagas sinemasisifus ...  Artjog
# 35364  claracxw nftasia maybe you know ignatianilu fr...  Artjog
# 35365  tbtb kangen ke jogja naik kereta terus ke artj...  Artjog
# 35366       sinemasisifus salsaistya ayo ke artjog lagi😁  Artjog
# 35367  cok iling pas nng artjog koncoe sigit ngongkon...  Artjog
#
#                       date_time  \
# 35363 2022-01-05 13:00:00+00:00
# 35364 2022-01-03 09:00:00+00:00
# 35365 2022-01-01 13:00:00+00:00
# 35366 2022-01-01 11:00:00+00:00
# 35367 2022-01-01 09:00:00+00:00
#
#                                                temp_list
# 35363  [akhlism, itskindadita, wikanbagas, sinemasisi...
# 35364  [claracxw, nftasia, maybe, you, know, ignatian...
# 35365  [tbtb, kangen, jogja, kereta, artjog, nonton, ...
# 35366    [sinemasisifus, salsaistya, ayo, artjog, lagi😁]
# 35367  [cok, iling, pas, nng, artjog, koncoe, sigit, ...

# %% [markdown]
# ###**5. Visualization**

# %% [markdown]
# > Dari dataframe *jogja* dan *jogjawis*, bisa kita lihat bahwa karena data tidak spesifik dan cukup luas cakupannya, maka kita akan mengenalkan tipe wisata yang akan menjadi 'tag' dari data-data tersebut

# %%
#List untuk daftar keyword
listWisata = ['gunung', 'pantai', 'danau', 'hutan', 'taman', 'air terjun', 'goa', 'bukit', 'lembah', 'kebun', 'taman nasional',               #Wisata Alam
              'candi', 'kuil', 'museum', 'monumen', 'cagar budaya', 'cagar alam', 'benteng', 'galeri seni', 'desa wisata', 'kampung wisata'   #Wisata Sejarah dan Budaya
              'kolam renang', 'waterpark', 'kebun binatang', 'taman bermain',                                                                 #Wisata Keluarga
              'arung jeram', 'mendaki gunung', 'hiking', 'paralayang', 'surfing', 'rafting', 'camping']                                       #Wisata Petualangan


#Temp_list hanya menyimpan 1 keyword saja, maka dibuat list untuk melakukan joint pada kata berdekatan pada tiap tweet
listCombine = [['air','terjun'], ['taman','nasional'], ['cagar','budaya'], ['cagar','alam'],
               ['galeri','seni'], ['kolam','renang'], ['kebun','binatang'], ['taman','bermain'],
               ['arung','jeram'], ['mendaki','gunung']]

# %%
# Definisi fungsi untuk melakukan joint kedua kata yang berdekatan pada temp_list
def combine(List1,List2):
  for key in List1:
    bin = []
    ind = 0
    while ind<(len(List2)-1):
      temp = [List2[ind],List2[ind+1]]
      if temp == key:
        List2.append(List2[ind]+' '+List2[ind+1])
        bin.append(List2[ind]) if List2[ind] not in bin else bin
        bin.append(List2[ind+1]) if List2[ind+1] not in bin else bin
      ind=ind+1
    for trash in bin:
      List2.remove(trash)
  return List2


# Definisi fungsi untuk mendeteksi apakah salah satu atau lebih kata pada listWisata ada dalam tweet
def tagging(List1, List2):
  temp = []
  for item in List1:
    for key in List2:
      if item == key:
        temp.append(item) if item not in temp else temp
  return temp

# %%
# dfJogja
# Combine
for ind in dfjogja.index:
  dfjogja['temp_list'][ind] = combine(listCombine,dfjogja['temp_list'][ind])

# Membuat kolom baru
dfjogja['taglist'] = [[] for _ in range(len(dfjogja))]

# Tagging
for ind in dfjogja.index:
  taglist = tagging(listWisata, dfjogja['temp_list'][ind])
  if dfjogja is not None :
    dfjogja['taglist'][ind] = taglist
# Out:
# <ipython-input-36-b6a49fb78666>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogja['temp_list'][ind] = combine(listCombine,dfjogja['temp_list'][ind])
# <ipython-input-36-b6a49fb78666>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogja['taglist'][ind] = taglist

# %%
# dfJogjawis
# Combine

for ind in dfjogjawis.index:
  dfjogjawis['temp_list'][ind] = combine(listCombine,dfjogjawis['temp_list'][ind])

# Membuat kolom baru
dfjogjawis['taglist'] = [[] for _ in range(len(dfjogjawis))]

# Tagging
for ind in dfjogjawis.index:
  taglist = tagging(listWisata, dfjogjawis['temp_list'][ind])
  if dfjogjawis is not None :
    dfjogjawis['taglist'][ind] = taglist
# Out:
# <ipython-input-37-754791679a9c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogjawis['temp_list'][ind] = combine(listCombine,dfjogjawis['temp_list'][ind])
# <ipython-input-37-754791679a9c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogjawis['taglist'][ind] = taglist

# %%
#drop temp_list karena sudah tidak dibutuhkan

dfjogja.drop(['temp_list'], axis=1, inplace=True)
dfjogjawis.drop(['temp_list'], axis=1, inplace=True)
dfwisata.drop(['temp_list'], axis=1, inplace=True)

# %% [markdown]
# > Melihat visualisasi dari dataframe dfjogja dan dfjogjawis

# %%
print("Dataframe Jogja".center(24," "))
top = Counter([item for sublist in dfjogja['taglist'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['new_tag','count']
temp.style.background_gradient(cmap='Greens')
# Out:
#     Dataframe Jogja
# <style type="text/css">
# #T_64d26_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_64d26_row1_col1 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_64d26_row2_col1 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_64d26_row3_col1 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_64d26_row4_col1 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_64d26_row5_col1 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_64d26_row6_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_64d26_row7_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_64d26_row8_col1 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_64d26_row9_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_64d26_row10_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_64d26_row11_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_64d26_row12_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_64d26_row13_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_64d26_row14_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_64d26_row15_col1, #T_64d26_row16_col1, #T_64d26_row17_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_64d26_row18_col1, #T_64d26_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_64d26" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64d26_level0_col0" class="col_heading level0 col0" >new_tag</th>
#       <th id="T_64d26_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64d26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64d26_row0_col0" class="data row0 col0" >pantai</td>
#       <td id="T_64d26_row0_col1" class="data row0 col1" >1919</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64d26_row1_col0" class="data row1 col0" >gunung</td>
#       <td id="T_64d26_row1_col1" class="data row1 col1" >1659</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64d26_row2_col0" class="data row2 col0" >taman</td>
#       <td id="T_64d26_row2_col1" class="data row2 col1" >1224</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64d26_row3_col0" class="data row3 col0" >museum</td>
#       <td id="T_64d26_row3_col1" class="data row3 col1" >845</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64d26_row4_col0" class="data row4 col0" >candi</td>
#       <td id="T_64d26_row4_col1" class="data row4 col1" >824</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_64d26_row5_col0" class="data row5 col0" >bukit</td>
#       <td id="T_64d26_row5_col1" class="data row5 col1" >355</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_64d26_row6_col0" class="data row6 col0" >hutan</td>
#       <td id="T_64d26_row6_col1" class="data row6 col1" >265</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_64d26_row7_col0" class="data row7 col0" >kebun</td>
#       <td id="T_64d26_row7_col1" class="data row7 col1" >237</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_64d26_row8_col0" class="data row8 col0" >goa</td>
#       <td id="T_64d26_row8_col1" class="data row8 col1" >229</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_64d26_row9_col0" class="data row9 col0" >benteng</td>
#       <td id="T_64d26_row9_col1" class="data row9 col1" >162</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_64d26_row10_col0" class="data row10 col0" >monumen</td>
#       <td id="T_64d26_row10_col1" class="data row10 col1" >150</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_64d26_row11_col0" class="data row11 col0" >camping</td>
#       <td id="T_64d26_row11_col1" class="data row11 col1" >103</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_64d26_row12_col0" class="data row12 col0" >air terjun</td>
#       <td id="T_64d26_row12_col1" class="data row12 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_64d26_row13_col0" class="data row13 col0" >paralayang</td>
#       <td id="T_64d26_row13_col1" class="data row13 col1" >76</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_64d26_row14_col0" class="data row14 col0" >cagar budaya</td>
#       <td id="T_64d26_row14_col1" class="data row14 col1" >64</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_64d26_row15_col0" class="data row15 col0" >lembah</td>
#       <td id="T_64d26_row15_col1" class="data row15 col1" >40</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_64d26_row16_col0" class="data row16 col0" >danau</td>
#       <td id="T_64d26_row16_col1" class="data row16 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_64d26_row17_col0" class="data row17 col0" >hiking</td>
#       <td id="T_64d26_row17_col1" class="data row17 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_64d26_row18_col0" class="data row18 col0" >kebun binatang</td>
#       <td id="T_64d26_row18_col1" class="data row18 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_64d26_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_64d26_row19_col0" class="data row19 col0" >waterpark</td>
#       <td id="T_64d26_row19_col1" class="data row19 col1" >19</td>
#     </tr>
#   </tbody>
# </table>

# %%
temp.iloc[:10].plot.bar(x = 'new_tag', y = 'count',
                        color = 'green',
                        title = 'Top 10 tag for dataframe dfjogja')
# Out:
# <Axes: title={'center': 'Top 10 tag for dataframe dfjogja'}, xlabel='new_tag'>

# %%
print("Dataframe Jogjawis".center(24," "))
top = Counter([item for sublist in dfjogjawis['taglist'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['new_tag','count']
temp.style.background_gradient(cmap='Blues')
# Out:
#    Dataframe Jogjawis
# <style type="text/css">
# #T_e7f66_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e7f66_row1_col1 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_e7f66_row2_col1 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_e7f66_row3_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_e7f66_row4_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_e7f66_row5_col1 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_e7f66_row6_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_e7f66_row7_col1 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_e7f66_row8_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_e7f66_row9_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_e7f66_row10_col1 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_e7f66_row11_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_e7f66_row12_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_e7f66_row13_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_e7f66_row14_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_e7f66_row15_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_e7f66_row16_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_e7f66_row17_col1, #T_e7f66_row18_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_e7f66_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_e7f66" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7f66_level0_col0" class="col_heading level0 col0" >new_tag</th>
#       <th id="T_e7f66_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7f66_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7f66_row0_col0" class="data row0 col0" >pantai</td>
#       <td id="T_e7f66_row0_col1" class="data row0 col1" >961</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7f66_row1_col0" class="data row1 col0" >kebun</td>
#       <td id="T_e7f66_row1_col1" class="data row1 col1" >911</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e7f66_row2_col0" class="data row2 col0" >goa</td>
#       <td id="T_e7f66_row2_col1" class="data row2 col1" >358</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e7f66_row3_col0" class="data row3 col0" >taman</td>
#       <td id="T_e7f66_row3_col1" class="data row3 col1" >354</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e7f66_row4_col0" class="data row4 col0" >gunung</td>
#       <td id="T_e7f66_row4_col1" class="data row4 col1" >340</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e7f66_row5_col0" class="data row5 col0" >candi</td>
#       <td id="T_e7f66_row5_col1" class="data row5 col1" >338</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e7f66_row6_col0" class="data row6 col0" >bukit</td>
#       <td id="T_e7f66_row6_col1" class="data row6 col1" >225</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e7f66_row7_col0" class="data row7 col0" >museum</td>
#       <td id="T_e7f66_row7_col1" class="data row7 col1" >212</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e7f66_row8_col0" class="data row8 col0" >hutan</td>
#       <td id="T_e7f66_row8_col1" class="data row8 col1" >124</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e7f66_row9_col0" class="data row9 col0" >camping</td>
#       <td id="T_e7f66_row9_col1" class="data row9 col1" >116</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e7f66_row10_col0" class="data row10 col0" >air terjun</td>
#       <td id="T_e7f66_row10_col1" class="data row10 col1" >94</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e7f66_row11_col0" class="data row11 col0" >paralayang</td>
#       <td id="T_e7f66_row11_col1" class="data row11 col1" >68</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e7f66_row12_col0" class="data row12 col0" >benteng</td>
#       <td id="T_e7f66_row12_col1" class="data row12 col1" >59</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e7f66_row13_col0" class="data row13 col0" >waterpark</td>
#       <td id="T_e7f66_row13_col1" class="data row13 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e7f66_row14_col0" class="data row14 col0" >danau</td>
#       <td id="T_e7f66_row14_col1" class="data row14 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e7f66_row15_col0" class="data row15 col0" >monumen</td>
#       <td id="T_e7f66_row15_col1" class="data row15 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e7f66_row16_col0" class="data row16 col0" >cagar budaya</td>
#       <td id="T_e7f66_row16_col1" class="data row16 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e7f66_row17_col0" class="data row17 col0" >lembah</td>
#       <td id="T_e7f66_row17_col1" class="data row17 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e7f66_row18_col0" class="data row18 col0" >kebun binatang</td>
#       <td id="T_e7f66_row18_col1" class="data row18 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e7f66_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e7f66_row19_col0" class="data row19 col0" >galeri seni</td>
#       <td id="T_e7f66_row19_col1" class="data row19 col1" >3</td>
#     </tr>
#   </tbody>
# </table>

# %%
temp.iloc[:10].plot.bar(x = 'new_tag', y = 'count',
                        color = 'skyblue',
                        title = 'Top 10 tag for dataframe dfjogjawis')
# Out:
# <Axes: title={'center': 'Top 10 tag for dataframe dfjogjawis'}, xlabel='new_tag'>

# %% [markdown]
# > Melihat perbandingan antara tweet yang berkaitan dengan wisata *dibandingkan dengan* tweet keseluruhan

# %%
for i in range(len(listWisata)):
  a = []
  a.append(listWisata[i])
  listWisata[i] = a

# %%
isWisata = 0
isNotWisata = 0
for lst in dfjogja['taglist']:
    if not lst:
        isNotWisata += 1
    else:
        isWisata += 1

pieValues = [isWisata, isNotWisata]
labels = ['Memiliki tag Wisata', 'TIDAK memiliki tag Wisata']
colors = ['green', 'red']
plt.pie(pieValues, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Perbanding Tweet yang Memiliki Tag Wisata dengan Tweet Keseluruhan di dfjogja')
plt.show()

# %%
isWisata = 0
isNotWisata = 0
for lst in dfjogjawis['taglist']:
    if not lst:
        isNotWisata += 1
    else:
        isWisata += 1

pieValues = [isWisata, isNotWisata]
labels = ['Memiliki tag Wisata', 'TIDAK memiliki tag Wisata']
colors = ['blue', 'red']
plt.pie(pieValues, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Perbanding Tweet yang Memiliki Tag Wisata dengan Tweet Keseluruhan di dfjogjawis')
plt.show()

# %% [markdown]
# > dari dataframe *dfWisata* kita bisa melihat beberapa insight yang dimiliki oleh data kita sebagai berikut

# %%
# calculate the total likes of each tag value
dflikes = dfwisata.groupby(["tag"]).sum()
dflikes['likes'] = dflikes.groupby(["tag"]).mean()['likes']

dflikes.drop(['id'], axis=1, inplace=True)
dflikes = dflikes.sort_values('likes', ascending=False)

# %%
dflikes.head(8)
# Out:
#                          likes
# tag
# Artjog                 73503.0
# Malioboro              60221.0
# Gembira Loka           27882.0
# Taman Sari             25826.0
# Masjid Gedhe Kauman    16109.0
# Pasar Kembang           7824.0
# Museum Sonobudoyo       4604.0
# Jogja National Museum   1819.0

# %%
# Select the top 10 tags by likes
dflikes= dflikes.nlargest(10, 'likes')

# Create a bar plot of the likes for each tag value
plt.figure(figsize=(10,6))
plt.bar(dflikes.index, dflikes['likes'], color='red')

# Set the chart title and axis labels
plt.title('Total Likes by Tag (Wisata Jogja Kota)')
plt.xlabel('Tag')
plt.ylabel('Likes')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %% [markdown]
# ###**6. Sentiment Analisis**

# %% [markdown]
# > **Sentimen dengan Transformer**

# %% [markdown]
# > Akan dipakai library Transformer untuk melakukan training model Machine Learning dimana library ini sangat andil dalam memproses data berupa urutan (sequence), seperti teks.
#
# > Model Transformer beroperasi dengan memproses input dalam sekaligus, menghilangkan kebutuhan untuk memproses input secara berurutan. Model ini bekerja dengan memanfaatkan mekanisme Attention, yaitu suatu teknik yang memungkinkan model untuk fokus pada bagian penting dari input yang berkaitan dengan tugas yang harus diselesaikan.
#
# > Beberapa komponen utama dari model Transformer antara lain:
#
# *   Encoder: bagian model yang bertanggung jawab untuk mengubah input ke dalam representasi latennya.
# *   Decoder: bagian model yang bertanggung jawab untuk menghasilkan output.
# *   Attention mechanism: suatu mekanisme yang memungkinkan model untuk fokus pada bagian penting dari input yang berkaitan dengan tugas yang harus diselesaikan.
#
# > library Transformer yang kami pakai adalah DistilBERT sebagai salah satu model NLP (Natural Language Processing)  yang dikembangkan oleh Hugging Face. Model ini merupakan versi yang lebih ringkas dari BERT (Bidirectional Encoder Representations from Transformers)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-multilingual-cased")
model = AutoModelForSequenceClassification.from_pretrained("distilbert-base-multilingual-cased", num_labels=3)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/466 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/542M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-multilingual-cased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# > Kita menggunakan Dataset IndoNLU sebagai dataset fine-tuning. indoNLU (Indonesian Natural Language Understanding) adalah proyek open-source yang bertujuan untuk mengembangkan model pemahaman bahasa alami untuk bahasa Indonesia, yang menyediakan dataset untuk model pemahaman bahasa alami berbahasa Indonesia

# %%
df_train = pd.read_csv('https://raw.githubusercontent.com/MichaelHamonangan/Analisis-Trend-Pariwisata-di-Yogyakarta-melalui-Media-Sosial/master/Dataset/train_preprocess.tsv', sep='\t', header=None)
df_test = pd.read_csv('https://raw.githubusercontent.com/MichaelHamonangan/Analisis-Trend-Pariwisata-di-Yogyakarta-melalui-Media-Sosial/master/Dataset/test_preprocess.tsv', sep='\t', header=None)

df_train.columns = ['text', 'label']
df_test.columns = ['text', 'label']

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    11000 non-null  object
#  1   label   11000 non-null  object
# dtypes: object(2)
# memory usage: 172.0+ KB

# %%
df_train.sample(3)
# Out:
#                                                    text     label
# 4554  apabila anda suka dengan menu makanan barat , ...  positive
# 2238  kami makan di sini untuk pertama kali dan kami...  negative
# 1708  makanan nya enak , sangat bervariasi . suasana...  positive

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    500 non-null    object
#  1   label   500 non-null    object
# dtypes: object(2)
# memory usage: 7.9+ KB

# %%
df_test.sample(3)
# Out:
#                                                   text     label
# 257  kalau tidak suka gaperlu didukung mas , dukung...   neutral
# 172  gue paling suka pakai susu ultra yang lowfat ....  positive
# 340                      artis cowok pop banci semua .  negative

# %%
max_length = 512

# %%
def sentiment_to_label(sentiment):
    if sentiment == 'positive':
        return 1
    elif sentiment == 'negative':
        return 0
    else:
        return 2

# %%
class SentimentDataset(Dataset):
    def __init__(self, df,tokenizer):
        self.encodings = tokenizer(df["text"].tolist(), truncation=True, padding=True)
        self.labels = df["label"].apply(sentiment_to_label).values

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_dataset = SentimentDataset(df_train, tokenizer)
test_dataset = SentimentDataset(df_test, tokenizer)

# %%
gc.collect()
torch.cuda.empty_cache()

# %%
training_args = TrainingArguments(
    output_dir='../model/',          # output directory
    num_train_epochs=5,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=100,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./logs',            # directory for storing logs
    logging_steps=200,
    fp16=True,
)

# %%
trainer = Trainer(model=model,  args=training_args, train_dataset=train_dataset,
                eval_dataset=test_dataset, tokenizer=tokenizer)

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3440' max='3440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3440/3440 08:12, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200</td>
#       <td>0.667900</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.434700</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.381100</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.271100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.250400</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.227400</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.201500</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.134800</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.119100</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.145600</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.087700</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.084600</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.059600</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.052200</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.047000</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.028300</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.033800</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3440, training_loss=0.18796982567670734, metrics={'train_runtime': 495.6288, 'train_samples_per_second': 110.97, 'train_steps_per_second': 6.941, 'total_flos': 2504506419360000.0, 'train_loss': 0.18796982567670734, 'epoch': 5.0})

# %%
model.save_pretrained('../model/smsa-distilbert-indo/')
tokenizer.save_pretrained('../model/smsa-distilbert-indo/')
# Out:
# ('../model/smsa-distilbert-indo/tokenizer_config.json',
#  '../model/smsa-distilbert-indo/special_tokens_map.json',
#  '../model/smsa-distilbert-indo/vocab.txt',
#  '../model/smsa-distilbert-indo/added_tokens.json',
#  '../model/smsa-distilbert-indo/tokenizer.json')

# %%
config = AutoConfig.from_pretrained('../model/smsa-distilbert-indo/', label2id={"negative":0,"positive":1,"neutral":2}, id2label={0:"negative",1:"positive",2:"neutral"})
model = AutoModelForSequenceClassification.from_pretrained('../model/smsa-distilbert-indo/', config=config).to(device)
tokenizer = AutoTokenizer.from_pretrained('../model/smsa-distilbert-indo/')
model.save_pretrained('../model/smsa-distilbert-indo/')

# %% [markdown]
# > **Testing hasil model**

# %%
predict = TextClassificationPipeline(model=model, tokenizer=tokenizer, device=0 if torch.cuda.is_available() else -1)

# %%
predict("saya suka produk ini")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a6e6b8c0599> in <cell line: 1>()
# ----> 1 predict("saya suka produk ini")
#
# NameError: name 'predict' is not defined

# %%
predict("ini adalah candi prambanan")
# Out:
# [{'label': 'neutral', 'score': 0.9958310723304749}]

# %%
predict("saya malas ke pantai")
# Out:
# [{'label': 'negative', 'score': 0.9988815188407898}]

# %% [markdown]
# > **Membuat Confusion Matrix untuk analisis Akurasi, Presisi, dan Recall**

# %%
from sklearn.metrics import confusion_matrix

# Train your model on the train dataset and make predictions on the test dataset
df_test_predict=df_test.copy()
df_test_predict.drop(['label'], axis=1, inplace=True)
df_test_predict['label_predict'] = ""
for ind in df_test_predict.index:
  temp_predict = predict(df_test_predict['text'][ind])[0]
  df_test_predict['label_predict'][ind] = temp_predict['label']

pred_labels = df_test_predict['label_predict'].values
true_labels = df_test['label'].values
labels = ["positive", "neutral", "negative"]

# Create the confusion matrix
cm = confusion_matrix(true_labels, pred_labels,labels=labels)

# Visualize the confusion matrix using a heatmap
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %% [markdown]
# > Menghitung Akurasi, Presisi, dan Recall dari model yang sudah di train

# %%
accuracy = sum([cm[i][i] for i in range(len(labels))]) / float(len(true_labels))

precision = []
recall = []
for i in range(len(labels)):
    tp = cm[i][i]
    fp = sum(cm[:, i]) - tp
    fn = sum(cm[i, :]) - tp
    precision.append(tp / float(tp + fp))
    recall.append(tp / float(tp + fn))

# %%
print('Accuracy:', accuracy, "\n")

for i in range(len(labels)):
    print('Precision for class', labels[i], ':', precision[i])
    print('Recall for class', labels[i], ':', recall[i], "\n")
# Out:
# Accuracy: 0.828
#
# Precision for class positive : 0.900523560209424
# Recall for class positive : 0.8269230769230769
#
# Precision for class neutral : 0.7966101694915254
# Recall for class neutral : 0.5340909090909091
#
# Precision for class negative : 0.78
# Recall for class negative : 0.9558823529411765

# %% [markdown]
# > Dalam analisis sentimen biner (mis., mengklasifikasikan ulasan film sebagai positif atau negatif), akurasi 80% atau lebih sering dianggap baik. Namun, untuk tugas yang lebih kompleks yang melibatkan beberapa kategori sentimen (mis., mengklasifikasikan umpan balik pelanggan menjadi positif, negatif, dan netral), ambang akurasi yang baik mungkin lebih rendah.
#
# > Dengan kata lain akurasi model hasil train pada projek ini sebesar 82.8% sudah dapat dianggap sebagai model yang cukup baik dalam melakukan analisis sentimen|

# %% [markdown]
# **Implementasi**

# %%
# Mengambil nilai yang reliable saja
dfjogja_filtered = dfjogja[dfjogja['taglist'].isin(listWisata)]
dfjogjawis_filtered = dfjogjawis[dfjogjawis['taglist'].isin(listWisata)]

# %%
dfjogja_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6987 entries, 143 to 451798
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         6987 non-null   int64
#  1   likes      6987 non-null   int64
#  2   source     6987 non-null   object
#  3   tweet      6987 non-null   object
#  4   date_time  6987 non-null   datetime64[ns, UTC]
#  5   taglist    6987 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(2), object(3)
# memory usage: 382.1+ KB

# %%
dfjogja_filtered.tail(5)
# Out:
#             id  likes           source  \
# 451685  451685      0        Instagram
# 451698  451698      0        Instagram
# 451761  451761      0     FlightAlerts
# 451776  451776      0  Twitter Web App
# 451798  451798      0  Twitter Web App
#
#                                                     tweet  \
# 451685  baru saja mengirim foto  air terjun randusari ...
# 451698  baru saja mengirim foto  air terjun randusari ...
# 451761  multi adsbx manoeuvring alert  at time wed dec...
# 451776  nu carelazisnu diy menyalurkan bantuan kepada ...
# 451798  ingatkan pentingnya menjaga kebersihan babinsa...
#
#                        date_time       taglist
# 451685 2022-12-07 06:00:00+00:00  [air terjun]
# 451698 2022-12-07 05:00:00+00:00  [air terjun]
# 451761 2022-12-07 04:00:00+00:00      [gunung]
# 451776 2022-12-07 04:00:00+00:00      [gunung]
# 451798 2022-12-07 04:00:00+00:00       [taman]

# %%
dfjogjawis_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3204 entries, 4 to 19559
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         3204 non-null   int64
#  1   likes      3204 non-null   int64
#  2   source     3204 non-null   object
#  3   tweet      3204 non-null   object
#  4   date_time  3204 non-null   datetime64[ns, UTC]
#  5   taglist    3204 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(2), object(3)
# memory usage: 175.2+ KB

# %%
dfjogjawis_filtered.tail(5)
# Out:
#           id  likes               source  \
# 19547  19547      0   OxfordBlue-Twitter
# 19549  19549      0              dlvr.it
# 19554  19554      0  Twitter for Android
# 19555  19555      5   Twitter for iPhone
# 19559  19559      0            Awtoshare
#
#                                                    tweet  \
# 19547  yogyakarta klasterisasi kawasan cagar budaya d...
# 19549  yogyakarta klasterisasi kawasan cagar budaya d...
# 19554  hari ini anggota batalyon a pelopor satbrimob ...
# 19555  menarik ini buat diangkat jadi wisata budayare...
# 19559               wisata museum affandi yogyakarta
#
#                       date_time         taglist
# 19547 2022-12-04 13:00:00+00:00  [cagar budaya]
# 19549 2022-12-04 13:00:00+00:00  [cagar budaya]
# 19554 2022-12-04 10:00:00+00:00        [pantai]
# 19555 2022-12-04 05:00:00+00:00        [pantai]
# 19559 2022-12-03 21:00:00+00:00        [museum]

# %% [markdown]
# > implementasi model machine learning

# %%
#Membuat kolom baru dfjogja_filtered
dfjogja_filtered['sentiment'] = ""

for ind in dfjogja_filtered.index:
  temp = predict(dfjogja_filtered['tweet'][ind])[0]
  dfjogja_filtered['sentiment'][ind] = temp['label']
# Out:
# <ipython-input-78-644f02960377>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogja_filtered['sentiment'] = ""
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# <ipython-input-78-644f02960377>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogja_filtered['sentiment'][ind] = temp['label']

# %%
def clean_tag(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', '', text)
    return text


dfjogja_filtered['taglist'].astype(str)
dfjogja_filtered['taglist'] = dfjogja_filtered['taglist'].apply(lambda x:clean_tag(x))
# Out:
# <ipython-input-79-70941da86b24>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogja_filtered['taglist'] = dfjogja_filtered['taglist'].apply(lambda x:clean_tag(x))

# %%
dfjogja_filtered.sample(10)
# Out:
#             id  likes               source  \
# 419923  419923      0            Instagram
# 293184  293184      0  Twitter for Android
# 416161  416161      0  Twitter for Android
# 394479  394479      0      Twitter Web App
# 349253  349253      0              dlvr.it
# 29276    29276      0      Twitter Web App
# 151390  151390      0  Twitter for Android
# 342807  342807      1      Twitter Web App
# 247502  247502      0  Twitter for Android
# 311645  311645      1      Twitter Web App
#
#                                                     tweet  \
# 419923  bukan hanya artefak tapi ia bicara ia menandai...
# 293184  collegemenfess nitip kakada yang bisa dimintai...
# 416161                         pantai selatan yogyakarta
# 394479  heru budi hartono resmi menjabat pj gubernur d...
# 349253  menikmati deburan gelombang pantai kukup yogya...
# 29276   sempat lari ke jogja pelaku pembunuhan istri s...
# 151390  shitlicious mau cari temen yang mau diajak mut...
# 342807  gak rela sampai kelewatan kan kemegahan konser...
# 247502  faktasepakbola mirip desain benteng keraton jo...
# 311645  siapa yang mau dapat tiket gratis nonton konse...
#
#                        date_time  taglist sentiment
# 419923 2022-11-09 12:00:00+00:00    candi  positive
# 293184 2022-12-22 11:00:00+00:00   pantai  positive
# 416161 2022-11-13 03:00:00+00:00   pantai   neutral
# 394479 2022-10-07 11:00:00+00:00   gunung   neutral
# 349253 2022-09-24 00:00:00+00:00   pantai  positive
# 29276  2022-07-24 08:00:00+00:00    candi   neutral
# 151390 2022-10-29 13:00:00+00:00   gunung  negative
# 342807 2022-09-29 11:00:00+00:00    candi   neutral
# 247502 2022-11-19 08:00:00+00:00  benteng   neutral
# 311645 2022-07-13 13:00:00+00:00    hutan  negative

# %%
#Membuat kolom baru dfjogjawis_filtered
dfjogjawis_filtered['sentiment'] = ""

for ind in dfjogjawis_filtered.index:
  temp = predict(dfjogjawis_filtered['tweet'][ind])[0]
  dfjogjawis_filtered['sentiment'][ind] = temp['label']

# %%
dfjogjawis_filtered['taglist'].astype(str)
dfjogjawis_filtered['taglist'] = dfjogjawis_filtered['taglist'].apply(lambda x:clean_tag(x))

# %%
dfjogjawis_filtered.sample(10)
# Out:
#           id  likes           source  \
# 16975  16975      0       Zapier.com
# 15319  15319      0  Twitter Web App
# 10013  10013      1  SocialChamp IO
# 11576  11576      0     twittbot.net
# 6622    6622      0     twittbot.net
# 14234  14234      0     twittbot.net
# 1139    1139      0        Awtoshare
# 6017    6017      0     twittbot.net
# 9828    9828      0     twittbot.net
# 14052  14052      0     twittbot.net
#
#                                                    tweet  \
# 16975   garut  pemerintah kabupaten garut jawa barat ...
# 15319  jagongan kalurahan sekapanewon rongkopbiro tap...
# 10013  wisata jogja  rekomendasi tempat wisata meliha...
# 11576  wisata alam kebun buah mangunan  jogjacitytour...
# 6622   wisata alam kebun buah mangunan  jogjacitytour...
# 14234  wisata alam kebun buah mangunan  jogjacitytour...
# 1139    tempat wisata pantai sundak gunungkidul jogja
# 6017   wisata alam kebun buah mangunan  jogjacitytour...
# 9828   reservasi dan info wisata goa pindul cp     to...
# 14052  wisata alam kebun buah mangunan  jogjacitytour...
#
#                       date_time taglist sentiment
# 16975 2022-03-07 14:00:00+00:00  gunung  positive
# 15319 2022-04-18 04:00:00+00:00   taman   neutral
# 10013 2022-09-09 14:00:00+00:00  gunung  positive
# 11576 2022-10-06 11:00:00+00:00   kebun  positive
# 6622  2022-06-04 02:00:00+00:00   kebun  positive
# 14234 2022-12-16 23:00:00+00:00   kebun  positive
# 1139  2022-01-01 15:00:00+00:00  pantai  positive
# 6017  2022-06-18 05:00:00+00:00   kebun  positive
# 9828  2022-09-13 19:00:00+00:00     goa   neutral
# 14052 2022-12-20 02:00:00+00:00   kebun  positive

# %%
#Membuat kolom baru
dfwisata['sentiment'] = ""

for ind in dfwisata.index:
  temp = predict(dfwisata['tweet'][ind])[0]
  dfwisata['sentiment'][ind] = temp['label']

# %%
dfwisata.sample(10)
# Out:
#           id  likes               source  \
# 2651    2652      1  Twitter for Android
# 21160  21161      0  Twitter for Android
# 12825  12826      0  Twitter for Android
# 6946    6947      6  Twitter for Android
# 24898  24899      0  Twitter for Android
# 7742    7743      0       Sunda Empire ✨
# 1015    1016      1  Twitter for Android
# 23654  23655     47   Twitter for iPhone
# 7282    7283      0  Twitter for Android
# 6386    6387      3  Twitter for Android
#
#                                                    tweet            tag  \
# 2651    kondangan jdi  ini pas ke rumah hantu maliobo...      Malioboro
# 21160  selasa  susilawati luhkan kab lombok baratpend...     Taman Sari
# 12825                arjibtect beli kembang apa ke pasar  Pasar Kembang
# 6946   poldadiy poldajogja ditbinmas binmas bisma mal...      Malioboro
# 24898                          bdngfess taman sari hujan     Taman Sari
# 7742   daks info kostan di jogja yg sekitaran maliobo...      Malioboro
# 1015              today partner panaspanasan di posko 💕       Malioboro
# 23654  eril klo lg di kampus penampilannya ga keliata...     Taman Sari
# 7282   video bersama teman lama anies baswedan makan ...      Malioboro
# 6386   ryawiedy solo semakin berseri ditangan dingin ...      Malioboro
#
#                       date_time sentiment
# 2651  2022-12-20 13:00:00+00:00  negative
# 21160 2022-08-09 11:00:00+00:00   neutral
# 12825 2022-08-26 05:00:00+00:00  positive
# 6946  2022-11-20 04:00:00+00:00   neutral
# 24898 2022-04-22 08:00:00+00:00  positive
# 7742  2022-11-12 08:00:00+00:00  negative
# 1015  2022-12-28 04:00:00+00:00   neutral
# 23654 2022-05-27 16:00:00+00:00  negative
# 7282  2022-11-17 03:00:00+00:00   neutral
# 6386  2022-11-25 14:00:00+00:00  positive

# %% [markdown]
# > Beberapa insight yang dapat dibuat berdasarkan data diatas

# %% [markdown]
# 1. Most Positive taglist of dfjogja_filtered and dfjogjawis_filtered

# %%
for ind in dfjogja_filtered.index:
  if dfjogja_filtered['sentiment'][ind] == "positive":
    dfjogja_filtered['sentiment_point'][ind] = 1
  elif dfjogja_filtered['sentiment'][ind] == "negative" :
    dfjogja_filtered['sentiment_point'][ind] = -1
  else : dfjogja_filtered['sentiment_point'][ind] = 0

# Create a new dataframe to store the result
sum_of_df = dfjogja_filtered.groupby('taglist').sum()['sentiment_point']
count_of_df = dfjogja_filtered.groupby('taglist').count()['sentiment_point']

# Create a new dataframe to store the result
df_result = pd.DataFrame({
    'value': sum_of_df.index,
    'sentiment_point': sum_of_df.values,
    'count' : count_of_df.values
})

C = df_result['count'].mean()
m = df_result['sentiment_point'].mean()
df_result['BayesianAverage'] = (C*m + df_result['count']*df_result['sentiment_point']) / (C + df_result['count'])

df_sorted = pd.DataFrame(df_result.sort_values(by=['BayesianAverage'], ascending=False))
df_sorted.style.background_gradient(cmap='Reds')
# Out:
# <ipython-input-102-71930b32d825>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogja_filtered['sentiment_point'][ind] = 1
# <ipython-input-102-71930b32d825>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else : dfjogja_filtered['sentiment_point'][ind] = 0
# <ipython-input-102-71930b32d825>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogja_filtered['sentiment_point'][ind] = -1
# <style type="text/css">
# #T_21f6d_row0_col1, #T_21f6d_row0_col3, #T_21f6d_row1_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_21f6d_row0_col2 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_21f6d_row1_col1 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_21f6d_row1_col3 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_21f6d_row2_col1 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_21f6d_row2_col2, #T_21f6d_row4_col2 {
#   background-color: #fb7656;
#   color: #f1f1f1;
# }
# #T_21f6d_row2_col3 {
#   background-color: #fc8565;
#   color: #f1f1f1;
# }
# #T_21f6d_row3_col1 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_21f6d_row3_col2 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_21f6d_row3_col3 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_21f6d_row4_col1 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_21f6d_row4_col3 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_21f6d_row5_col1 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_21f6d_row5_col2 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_21f6d_row5_col3 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_21f6d_row6_col1, #T_21f6d_row12_col1, #T_21f6d_row25_col3 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_21f6d_row6_col2, #T_21f6d_row7_col2, #T_21f6d_row8_col2, #T_21f6d_row9_col2, #T_21f6d_row10_col2, #T_21f6d_row11_col2, #T_21f6d_row12_col2, #T_21f6d_row13_col2, #T_21f6d_row27_col1, #T_21f6d_row27_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_21f6d_row6_col3, #T_21f6d_row7_col3, #T_21f6d_row8_col3, #T_21f6d_row9_col3, #T_21f6d_row10_col3, #T_21f6d_row11_col3 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_21f6d_row7_col1, #T_21f6d_row8_col1, #T_21f6d_row9_col1, #T_21f6d_row16_col1, #T_21f6d_row20_col2 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_21f6d_row10_col1, #T_21f6d_row13_col1, #T_21f6d_row19_col2, #T_21f6d_row22_col2, #T_21f6d_row24_col1, #T_21f6d_row26_col3 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_21f6d_row11_col1, #T_21f6d_row24_col2 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_21f6d_row12_col3, #T_21f6d_row13_col3, #T_21f6d_row14_col3, #T_21f6d_row20_col1, #T_21f6d_row26_col1 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_21f6d_row14_col1, #T_21f6d_row21_col3 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_21f6d_row14_col2, #T_21f6d_row16_col2, #T_21f6d_row22_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_21f6d_row15_col1, #T_21f6d_row19_col3, #T_21f6d_row20_col3 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_21f6d_row15_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_21f6d_row15_col3, #T_21f6d_row16_col3 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_21f6d_row17_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_21f6d_row17_col2, #T_21f6d_row18_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_21f6d_row17_col3, #T_21f6d_row18_col3 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_21f6d_row18_col2 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_21f6d_row19_col1 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_21f6d_row21_col1 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_21f6d_row21_col2 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_21f6d_row22_col3 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_21f6d_row23_col1 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_21f6d_row23_col2 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_21f6d_row23_col3, #T_21f6d_row24_col3 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_21f6d_row25_col1, #T_21f6d_row27_col2 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_21f6d_row25_col2 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_21f6d_row26_col2 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# </style>
# <table id="T_21f6d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21f6d_level0_col0" class="col_heading level0 col0" >value</th>
#       <th id="T_21f6d_level0_col1" class="col_heading level0 col1" >sentiment_point</th>
#       <th id="T_21f6d_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_21f6d_level0_col3" class="col_heading level0 col3" >BayesianAverage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21f6d_level0_row0" class="row_heading level0 row0" >24</th>
#       <td id="T_21f6d_row0_col0" class="data row0 col0" >taman</td>
#       <td id="T_21f6d_row0_col1" class="data row0 col1" >376</td>
#       <td id="T_21f6d_row0_col2" class="data row0 col2" >1133</td>
#       <td id="T_21f6d_row0_col3" class="data row0 col3" >317.759314</td>
#     </tr>
#     <tr>
#       <th id="T_21f6d_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_21f6d_row1_col0" class="data row1 col0" >pantai</td>
#       <td id="T_21f6d_row1_col1" class="data row1 col1" >326</td>
#       <td id="T_21f6d_row1_col2" class="data row1 col2" >1570</td>
#       <td id="T_21f6d_row1_col3" class="data row1 col3" >288.604173</td>
#     </tr>
#     <tr>
#       <th id="T_21f6d_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_21f6d_row2_col0" class="data row2 col0" >museum</td>
#       <td id="T_21f6d_row2_col1" class="data row2 col1" >184</td>
#       <td id="T_21f6d_row2_col2" class="data row2 col2" >726</td>
#       <td id="T_21f6d_row2_col3" class="data row2 col3" >150.573268</td>
#     </tr>
#     <tr>
#       <th id="T_21f6d_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_21f6d_row3_col0" class="data row3 col0" >gunung</td>
#       <td id="T_21f6d_row3_col1" class="data row3 col1" >163</td>
#       <td id="T_21f6d_row3_col2" class="data row3 col2" >1374</td>
#       <td id="T_21f6d_row3_col3" class="data row3 col3" >146.142520</td>
#     </tr>
#     <tr>
#       <th id="T_21f6d_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_21f6d_row4_col0" class="data row4 col0" >candi</td>
#       <td id="T_21f6d_row4_col1" class="data row4 col1" >149</td>
#       <td id="T_21f6d_row4_col2" class="data row4 col2" >725</td>
#       <td id="T_21f6d_row4_col3" class="data row4 col3" >124.500928</td>
#     </tr>
#     <tr>
#       <th id="T_21f6d_level0_row5" class="row_heading level0 row5" >13</th>
#       <td id="T_21f6d_row5_col0" class="data row5 col0" >kebun</td>
#       <td id="T_21f6d_row5_col1" class="data row5 col1" >124</td>
#       <td id="T_21f6d_row5_col2" class="data row5 col2" >213</td>
#       <td id="T_21f6d_row5_col3" class="data row5 col3" >85.869263</td>
#     </tr>
#     <tr>
#       <th id="T_21f6d_level0_row6" class="row_heading level0 row6" >26</th>
#       <td id="T_21f6d_row6_col0" class="data row6 col0" >taman nasional</td>
#       <td id="T_21f6d_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_21f6d_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_21f6d_row6_col3" class="data row6 col3" >52.897462</td>
#     </tr>
#     <tr>
#       <th id="T_21f6d_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_21f6d_row7_col0" class="data row7 col0" >arung jeram</td>
#       <td id="T_21f6d_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_21f6d_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_21f6d_row7_col3" class="data row7 col3" >52.711755</td>
#     </tr>
#     <tr>
#       <th id="T_21f6d_level0_row8" class="row_heading level0 row8" >17</th>
#       <td id="T_21f6d_row8_col0" class="data row8 col0" >mendaki gunung</td>
#       <td id="T_21f6d_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_21f6d_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_21f6d_row8_col3" class="data row8 col3" >52.699876</td>
#     </tr>
#     <tr>
#       <th id="T_21f6d_level0_row9" class="row_heading level0 row9" >23</th>
#       <td id="T_21f6d_row9_col0" class="data row9 col0" >surfing</td>
#       <td id="T_21f6d_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_21f6d_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_21f6d_row9_col3" class="data row9 col3" >52.699876</td>
#     </tr>
#     <tr>
#       <th id="T_

# %%
dfjogjawis_filtered['sentiment_point'] = 0
for ind in dfjogjawis_filtered.index:
  if dfjogjawis_filtered['sentiment'][ind] == "positive":
    dfjogjawis_filtered['sentiment_point'][ind] = 1
  elif dfjogjawis_filtered['sentiment'][ind] == "negative" :
    dfjogjawis_filtered['sentiment_point'][ind] = -1

# Create a new dataframe to store the result
sum_of_df = dfjogjawis_filtered.groupby('taglist').sum()['sentiment_point']
count_of_df = dfjogjawis_filtered.groupby('taglist').count()['sentiment_point']

# Create a new dataframe to store the result
df_result = pd.DataFrame({
    'value': sum_of_df.index,
    'sentiment_point': sum_of_df.values,
    'count' : count_of_df.values
})

C = df_result['count'].mean()
m = df_result['sentiment_point'].mean()
df_result['BayesianAverage'] = (C*m + df_result['count']*df_result['sentiment_point']) / (C + df_result['count'])

df_sorted = pd.DataFrame(df_result.sort_values(by=['BayesianAverage'], ascending=False))
df_sorted.style.background_gradient(cmap='BuPu')
# Out:
# <ipython-input-87-ddeac423c010>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogjawis_filtered['sentiment_point'] = 0
# <ipython-input-87-ddeac423c010>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogjawis_filtered['sentiment_point'][ind] = 1
# <ipython-input-87-ddeac423c010>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfjogjawis_filtered['sentiment_point'][ind] = -1
# <style type="text/css">
# #T_73d85_row0_col1, #T_73d85_row0_col2, #T_73d85_row0_col3 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_73d85_row1_col1 {
#   background-color: #b6cde3;
#   color: #000000;
# }
# #T_73d85_row1_col2 {
#   background-color: #863394;
#   color: #f1f1f1;
# }
# #T_73d85_row1_col3 {
#   background-color: #c1d4e7;
#   color: #000000;
# }
# #T_73d85_row2_col1 {
#   background-color: #ccddec;
#   color: #000000;
# }
# #T_73d85_row2_col2 {
#   background-color: #b7cee3;
#   color: #000000;
# }
# #T_73d85_row2_col3, #T_73d85_row3_col1 {
#   background-color: #deeaf3;
#   color: #000000;
# }
# #T_73d85_row3_col2 {
#   background-color: #c2d5e7;
#   color: #000000;
# }
# #T_73d85_row3_col3 {
#   background-color: #e9f2f7;
#   color: #000000;
# }
# #T_73d85_row4_col1 {
#   background-color: #e1ecf4;
#   color: #000000;
# }
# #T_73d85_row4_col2 {
#   background-color: #c3d6e8;
#   color: #000000;
# }
# #T_73d85_row4_col3 {
#   background-color: #eaf3f8;
#   color: #000000;
# }
# #T_73d85_row5_col1 {
#   background-color: #e0ecf4;
#   color: #000000;
# }
# #T_73d85_row5_col2 {
#   background-color: #d7e5f0;
#   color: #000000;
# }
# #T_73d85_row5_col3 {
#   background-color: #ebf3f8;
#   color: #000000;
# }
# #T_73d85_row6_col1, #T_73d85_row6_col2, #T_73d85_row7_col1, #T_73d85_row7_col2, #T_73d85_row8_col1, #T_73d85_row8_col2, #T_73d85_row9_col1, #T_73d85_row9_col2, #T_73d85_row10_col1, #T_73d85_row10_col2, #T_73d85_row12_col1, #T_73d85_row23_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_73d85_row6_col3, #T_73d85_row7_col3, #T_73d85_row8_col3, #T_73d85_row9_col3, #T_73d85_row10_col3, #T_73d85_row21_col1 {
#   background-color: #eff6fa;
#   color: #000000;
# }
# #T_73d85_row11_col1, #T_73d85_row11_col2, #T_73d85_row12_col2, #T_73d85_row13_col1, #T_73d85_row16_col1 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_73d85_row11_col3, #T_73d85_row12_col3, #T_73d85_row13_col3, #T_73d85_row14_col3, #T_73d85_row15_col3 {
#   background-color: #f0f7fa;
#   color: #000000;
# }
# #T_73d85_row13_col2, #T_73d85_row14_col1, #T_73d85_row15_col1, #T_73d85_row18_col1, #T_73d85_row22_col3 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_73d85_row14_col2, #T_73d85_row15_col2, #T_73d85_row16_col2 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_73d85_row16_col3, #T_73d85_row17_col3, #T_73d85_row18_col3 {
#   background-color: #f1f7fa;
#   color: #000000;
# }
# #T_73d85_row17_col1 {
#   background-color: #ebf4f8;
#   color: #000000;
# }
# #T_73d85_row17_col2 {
#   background-color: #e8f1f7;
#   color: #000000;
# }
# #T_73d85_row18_col2 {
#   background-color: #f3f9fc;
#   color: #000000;
# }
# #T_73d85_row19_col1, #T_73d85_row19_col2, #T_73d85_row19_col3, #T_73d85_row20_col3, #T_73d85_row23_col1 {
#   background-color: #f1f8fb;
#   color: #000000;
# }
# #T_73d85_row20_col1, #T_73d85_row21_col3, #T_73d85_row22_col1 {
#   background-color: #f3f9fb;
#   color: #000000;
# }
# #T_73d85_row20_col2 {
#   background-color: #f2f8fb;
#   color: #000000;
# }
# #T_73d85_row21_col2 {
#   background-color: #e1edf5;
#   color: #000000;
# }
# #T_73d85_row22_col2 {
#   background-color: #dbe8f2;
#   color: #000000;
# }
# #T_73d85_row23_col2 {
#   background-color: #9fbcda;
#   color: #000000;
# }
# </style>
# <table id="T_73d85" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73d85_level0_col0" class="col_heading level0 col0" >value</th>
#       <th id="T_73d85_level0_col1" class="col_heading level0 col1" >sentiment_point</th>
#       <th id="T_73d85_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_73d85_level0_col3" class="col_heading level0 col3" >BayesianAverage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73d85_level0_row0" class="row_heading level0 row0" >13</th>
#       <td id="T_73d85_row0_col0" class="data row0 col0" >kebun</td>
#       <td id="T_73d85_row0_col1" class="data row0 col1" >871</td>
#       <td id="T_73d85_row0_col2" class="data row0 col2" >891</td>
#       <td id="T_73d85_row0_col3" class="data row0 col3" >767.535871</td>
#     </tr>
#     <tr>
#       <th id="T_73d85_level0_row1" class="row_heading level0 row1" >19</th>
#       <td id="T_73d85_row1_col0" class="data row1 col0" >pantai</td>
#       <td id="T_73d85_row1_col1" class="data row1 col1" >246</td>
#       <td id="T_73d85_row1_col2" class="data row1 col2" >697</td>
#       <td id="T_73d85_row1_col3" class="data row1 col3" >218.833835</td>
#     </tr>
#     <tr>
#       <th id="T_73d85_level0_row2" class="row_heading level0 row2" >22</th>
#       <td id="T_73d85_row2_col0" class="data row2 col0" >taman</td>
#       <td id="T_73d85_row2_col1" class="data row2 col1" >174</td>
#       <td id="T_73d85_row2_col2" class="data row2 col2" >250</td>
#       <td id="T_73d85_row2_col3" class="data row2 col3" >140.233377</td>
#     </tr>
#     <tr>
#       <th id="T_73d85_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_73d85_row3_col0" class="data row3 col0" >gunung</td>
#       <td id="T_73d85_row3_col1" class="data row3 col1" >117</td>
#       <td id="T_73d85_row3_col2" class="data row3 col2" >216</td>
#       <td id="T_73d85_row3_col3" class="data row3 col3" >101.721030</td>
#     </tr>
#     <tr>
#       <th id="T_73d85_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_73d85_row4_col0" class="data row4 col0" >candi</td>
#       <td id="T_73d85_row4_col1" class="data row4 col1" >105</td>
#       <td id="T_73d85_row4_col2" class="data row4 col2" >212</td>
#       <td id="T_73d85_row4_col3" class="data row4 col3" >94.180897</td>
#     </tr>
#     <tr>
#       <th id="T_73d85_level0_row5" class="row_heading level0 row5" >18</th>
#       <td id="T_73d85_row5_col0" class="data row5 col0" >museum</td>
#       <td id="T_73d85_row5_col1" class="data row5 col1" >109</td>
#       <td id="T_73d85_row5_col2" class="data row5 col2" >145</td>
#       <td id="T_73d85_row5_col3" class="data row5 col3" >93.660682</td>
#     </tr>
#     <tr>
#       <th id="T_73d85_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_73d85_row6_col0" class="data row6 col0" >galeri seni</td>
#       <td id="T_73d85_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_73d85_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_73d85_row6_col3" class="data row6 col3" >76.434944</td>
#     </tr>
#     <tr>
#       <th id="T_73d85_level0_row7" class="row_heading level0 row7" >4</th>
#       <td id="T_73d85_row7_col0" class="data row7 col0" >cagar alam</td>
#       <td id="T_73d85_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_73d85_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_73d85_row7_col3" class="data row7 col3" >76.434944</td>
#     </tr>
#     <tr>
#       <th id="T_73d85_level0_row8" class="row_heading level0 row8" >16</th>
#       <td id="T_73d85_row8_col0" class="data row8 col0" >mendaki gunung</td>
#       <td id="T_73d85_row8_col1" class="data row8 col1" >-1</td>
#       <td id="T_73d85_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_73d85_row8_col3" class="data row8 col3" >76.420074</td>
#     </tr>
#     <tr>
#       <th id="T_73d85_level0_row9" class="row_heading level0 row9" >21</th>
#       <td id="T_73d85_row9_col0" class="data row9 col0" >rafting</td>
#       <td id="T_73d85_row9_col1" class="data row9 col1" >-1</td>
#       <td id="T_73d85_row9_col2" class="data row9 col2" >2</td>
#       <td id="T_73d85_row9_col3" class="data row9 col3" >75.848708</td>
#     </tr>
#     <tr>
#       <th id="T_73d85_level0_row10" class="row_heading level0 row10" >1</th>
#       <td id="T_73d85_row10_col0" class="data row10 col0" >arung jeram</td>
#       <td id="T_73d85_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_73d85_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_73d85_row10_col3" class="data row10 col3" >75.307692</td>
#     </tr>
#     <tr>
#       <th id="T_73d85_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_73d85_row11_col0" class="data row11 col0" >kebun binatang</td>
#       <td id="T_73d85_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_73d85_row11_col2" class="data row11 col2" >7</td>
#       <td id="T_73d85_row11_col3" class="data row11 col3" >73.313167</td>
#     </tr>
#     <tr>
#       <th id="T

# %% [markdown]
# > Terlihat bahwa dari kedua dataset tersebut, taglist wisata dengan nilai tertinggi berdasarkan nilai sentimennya menggunakan BayesianAverage memiliki 5 besar yang sama secara berurut yaitu
#
#
#
# *   **Pantai**
# *   **Taman**
# *   **Museum**
# *   **Candi**
# *   **Gunung**
#
#
#
# > Dan beberapa taglist yang cenderung memiliki nilai BayesianAverage yang terbawah adalah
#
# *   **Kebun**
# *   **Goa**
# *   **Hutan**

# %% [markdown]
# 2. Most Positive taglist of dfwisata

# %%
dfwisata['sentiment_point'] = 0
for ind in dfwisata.index:
  if dfwisata['sentiment'][ind] == "positive":
    dfwisata['sentiment_point'][ind] = 1
  elif dfwisata['sentiment'][ind] == "negative" :
    dfwisata['sentiment_point'][ind] = -1

# Create a new dataframe to store the result
sum_of_df = dfwisata.groupby('tag').sum()['sentiment_point']
count_of_df = dfwisata.groupby('tag').count()['sentiment_point']

# Create a new dataframe to store the result
df_result = pd.DataFrame({
    'value': sum_of_df.index,
    'sentiment_point': sum_of_df.values,
    'count' : count_of_df.values
})

C = df_result['count'].mean()
m = df_result['sentiment_point'].mean()
df_result['BayesianAverage'] = (C*m + df_result['count']*df_result['sentiment_point']) / (C + df_result['count'])

df_sorted = pd.DataFrame(df_result.sort_values(by=['BayesianAverage'], ascending=False))
df_sorted.style.background_gradient(cmap='Greens')
# Out:
# <ipython-input-103-56c9ce51a8bb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfwisata['sentiment_point'][ind] = 1
# <ipython-input-103-56c9ce51a8bb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfwisata['sentiment_point'][ind] = -1
# <style type="text/css">
# #T_b958f_row0_col1, #T_b958f_row0_col3, #T_b958f_row35_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_b958f_row0_col2 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_b958f_row1_col1 {
#   background-color: #005e26;
#   color: #f1f1f1;
# }
# #T_b958f_row1_col2 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_b958f_row1_col3 {
#   background-color: #006227;
#   color: #f1f1f1;
# }
# #T_b958f_row2_col1 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_b958f_row2_col2 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_b958f_row2_col3 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_b958f_row3_col1 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_b958f_row3_col2 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_b958f_row3_col3 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_b958f_row4_col1, #T_b958f_row4_col3, #T_b958f_row5_col3 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_b958f_row4_col2 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_b958f_row5_col1 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_b958f_row5_col2 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_b958f_row6_col1 {
#   background-color: #0e7936;
#   color: #f1f1f1;
# }
# #T_b958f_row6_col2 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_b958f_row6_col3, #T_b958f_row7_col1, #T_b958f_row7_col3 {
#   background-color: #18823d;
#   color: #f1f1f1;
# }
# #T_b958f_row7_col2, #T_b958f_row9_col2 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_b958f_row8_col1, #T_b958f_row11_col1 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_b958f_row8_col2, #T_b958f_row19_col2 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_b958f_row8_col3 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_b958f_row9_col1, #T_b958f_row19_col1 {
#   background-color: #248c46;
#   color: #f1f1f1;
# }
# #T_b958f_row9_col3, #T_b958f_row10_col3, #T_b958f_row11_col3, #T_b958f_row12_col3, #T_b958f_row13_col3, #T_b958f_row14_col3, #T_b958f_row15_col3, #T_b958f_row16_col3, #T_b958f_row17_col3, #T_b958f_row18_col3, #T_b958f_row19_col3, #T_b958f_row20_col3, #T_b958f_row21_col3, #T_b958f_row22_col3, #T_b958f_row23_col3, #T_b958f_row24_col3, #T_b958f_row25_col3, #T_b958f_row26_col3, #T_b958f_row27_col3, #T_b958f_row28_col3, #T_b958f_row29_col3, #T_b958f_row30_col3, #T_b958f_row31_col3, #T_b958f_row32_col3, #T_b958f_row33_col3 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_b958f_row10_col1, #T_b958f_row13_col1, #T_b958f_row16_col1, #T_b958f_row21_col1, #T_b958f_row25_col1, #T_b958f_row28_col1 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_b958f_row10_col2, #T_b958f_row11_col2, #T_b958f_row12_col2, #T_b958f_row13_col2, #T_b958f_row14_col2, #T_b958f_row15_col2, #T_b958f_row16_col2, #T_b958f_row17_col2, #T_b958f_row18_col2, #T_b958f_row20_col2, #T_b958f_row21_col2, #T_b958f_row22_col2, #T_b958f_row23_col2, #T_b958f_row24_col2, #T_b958f_row25_col2, #T_b958f_row26_col2, #T_b958f_row27_col2, #T_b958f_row28_col2, #T_b958f_row29_col2, #T_b958f_row30_col2, #T_b958f_row31_col2, #T_b958f_row32_col2, #T_b958f_row35_col1, #T_b958f_row35_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_b958f_row12_col1, #T_b958f_row14_col1, #T_b958f_row15_col1, #T_b958f_row17_col1, #T_b958f_row18_col1, #T_b958f_row20_col1, #T_b958f_row22_col1, #T_b958f_row23_col1, #T_b958f_row24_col1, #T_b958f_row26_col1, #T_b958f_row27_col1, #T_b958f_row29_col1, #T_b958f_row30_col1, #T_b958f_row31_col1, #T_b958f_row32_col1 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_b958f_row33_col1 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_b958f_row33_col2 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_b958f_row34_col1 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_b958f_row34_col2 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_b958f_row34_col3 {
#   background-color: #8ace88;
#   color: #000000;
# }
# </style>
# <table id="T_b958f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b958f_level0_col0" class="col_heading level0 col0" >value</th>
#       <th id="T_b958f_level0_col1" class="col_heading level0 col1" >sentiment_point</th>
#       <th id="T_b958f_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_b958f_level0_col3" class="col_heading level0 col3" >BayesianAverage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b958f_level0_row0" class="row_heading level0 row0" >27</th>
#       <td id="T_b958f_row0_col0" class="data row0 col0" >Pasar Kembang</td>
#       <td id="T_b958f_row0_col1" class="data row0 col1" >513</td>
#       <td id="T_b958f_row0_col2" class="data row0 col2" >3273</td>
#       <td id="T_b958f_row0_col3" class="data row0 col3" >393.992660</td>
#     </tr>
#     <tr>
#       <th id="T_b958f_level0_row1" class="row_heading level0 row1" >8</th>
#       <td id="T_b958f_row1_col0" class="data row1 col0" >Gembira Loka</td>
#       <td id="T_b958f_row1_col1" class="data row1 col1" >347</td>
#       <td id="T_b958f_row1_col2" class="data row1 col2" >1953</td>
#       <td id="T_b958f_row1_col3" class="data row1 col3" >227.207045</td>
#     </tr>
#     <tr>
#       <th id="T_b958f_level0_row2" class="row_heading level0 row2" >31</th>
#       <td id="T_b958f_row2_col0" class="data row2 col0" >Taman Sari</td>
#       <td id="T_b958f_row2_col1" class="data row2 col1" >101</td>
#       <td id="T_b958f_row2_col2" class="data row2 col2" >9798</td>
#       <td id="T_b958f_row2_col3" class="data row2 col3" >90.166886</td>
#     </tr>
#     <tr>
#       <th id="T_b958f_level0_row3" class="row_heading level0 row3" >26</th>
#       <td id="T_b958f_row3_col0" class="data row3 col0" >Museum Sonobudoyo</td>
#       <td id="T_b958f_row3_col1" class="data row3 col1" >158</td>
#       <td id="T_b958f_row3_col2" class="data row3 col2" >658</td>
#       <td id="T_b958f_row3_col3" class="data row3 col3" >51.498405</td>
#     </tr>
#     <tr>
#       <th id="T_b958f_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_b958f_row4_col0" class="data row4 col0" >Jogja National Museum</td>
#       <td id="T_b958f_row4_col1" class="data row4 col1" >79</td>
#       <td id="T_b958f_row4_col2" class="data row4 col2" >558</td>
#       <td id="T_b958f_row4_col3" class="data row4 col3" >14.781840</td>
#     </tr>
#     <tr>
#       <th id="T_b958f_level0_row5" class="row_heading level0 row5" >24</th>
#       <td id="T_b958f_row5_col0" class="data row5 col0" >Museum Sandi</td>
#       <td id="T_b958f_row5_col1" class="data row5 col1" >89</td>
#       <td id="T_b958f_row5_col2" class="data row5 col2" >445</td>
#       <td id="T_b958f_row5_col3" class="data row5 col3" >12.744590</td>
#     </tr>
#     <tr>
#       <th id="T_b958f_level0_row6" class="row_heading level0 row6" >34</th>
#       <td id="T_b958f_row6_col0" class="data row6 col0" >Wisata Rejowinangun</td>
#       <td id="T_b958f_row6_col1" class="data row6 col1" >142</td>
#       <td id="T_b958f_row6_col2" class="data row6 col2" >201</td>
#       <td id="T_b958f_row6_col3" class="data row6 col3" >5.729018</td>
#     </tr>
#     <tr>
#       <th id="T_b958f_level0_row7" class="row_heading level0 row7" >17</th>
#       <td id="T_b958f_row7_col0" class="data row7 col0" >Museum Benteng Vredeburg</td>
#       <td id="T_b958f_row7_col1" class="data row7 col1" >71</td>
#       <td id="T_b958f_row7_col2" class="data row7 col2" >358</td>
#       <td id="T_b958f_row7_col3" class="data row7 col3" >2.611671</td>
#     </tr>
#     <tr>
#       <th id="T_b958f_level0_row8" class="row_heading level0 row8" >30</th>
#       <td id="T_b958f_row8_col0" class="data row8 col0" >Situs Warungboto</td>
#       <td id="T_b958f_row8_col1" class="data row8 col1" >11</td>
#       <td id="T_b958f_row8_col2" class="data row8 col2" >110</td>
#       <td id="T_b958f_row8_col3" class="data row8 col3" >-19.984530</td>
#     </tr>
#     <tr>
#       <th id="T_b958f_level0_row9" class="row_heading level0 row9" >32</th>
#       <td id="T_b958f_row9_col0" class="data row9 col0" >Tugu Jam Jogja</td>
#       <td id="T_b958f_row9_col1" class="data row9 col1" >-16</td>
#       <td id="T_b958f_row9_col2

# %% [markdown]
# > Terlihat bahwa tag wisata dengan **nilai tertinggi** berdasarkan nilai sentimennya menggunakan BayesianAverage adalah
#
# *   **Pasar kembang**
# *   **Taman Sari**
# *   **Gembira Loka**
# *   **Museum Sonobudoyo**
# *   **Museum Nasional Yogyakarta**
# *   **Museum Sandi**
# *   **Wisata Rejowinangun**
# *   **Museum Benteng Vredeburg**
#
# > Dan beberapa taglist yang cenderung memiliki nilai BayesianAverage yang **terbawah** adalah
#
# *   **Masjid Gedhe Kauman**
# *   **Artjog**
# *   **Malioboro**

# %% [markdown]
# 3. Tweets terpositif terkait wisata kota jogja dengan likes terbanyak

# %%
# calculate the total likes of each tag value
dflikes_sum = dfwisata.loc[dfwisata['sentiment'] == 'positive'].groupby(["tag"]).sum()
dflikes_sum['likes'] = dflikes_sum.groupby(["tag"]).mean()['likes']
dflikes_sum.drop(['id'], axis=1, inplace=True)
dflikes_sum = dflikes_sum.sort_values('likes', ascending=False)
# Select the top 10 tags by likes
dflikes_sum= dflikes_sum.nlargest(10, 'likes')


# calculate the mean of likes of each tag value
dflikes_mean = dfwisata.loc[dfwisata['sentiment'] == 'positive'].groupby(["tag"]).mean()
dflikes_mean['likes'] = dflikes_mean.groupby(["tag"]).mean()['likes']
dflikes_mean.drop(['id'], axis=1, inplace=True)
dflikes_mean = dflikes_mean.sort_values('likes', ascending=False)
# Select the top 10 tags by likes
dflikes_mean= dflikes_mean.nlargest(10, 'likes')

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 5))

# Create a bar plot of the total likes
axs[0].bar(dflikes_sum.index, dflikes_sum['likes'], color='red')
axs[0].set_title('Sum of Likes by Tag on positive only sentiment')
axs[0].set_xticklabels(dflikes_sum.index, rotation=90)


# Create a bar plot of the mean of likes
axs[1].bar(dflikes_mean.index, dflikes_mean['likes'], color='red')
axs[1].set_title('Mean of Likes by Tag on positive only sentiment')
axs[1].set_xticklabels(dflikes_mean.index, rotation=90)

# adjust the spacing between the subplots
plt.subplots_adjust(wspace=0.2)

# show the plot
plt.show()
# Out:
# <ipython-input-90-a9b151af0874>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(dflikes_sum.index, rotation=90)
# <ipython-input-90-a9b151af0874>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels(dflikes_mean.index, rotation=90)

# %%
# calculate the total likes of each tag value
dflikes_sum = dfwisata.loc[dfwisata['sentiment'] == 'negative'].groupby(["tag"]).sum()
dflikes_sum['likes'] = dflikes_sum.groupby(["tag"]).mean()['likes']
dflikes_sum.drop(['id'], axis=1, inplace=True)
dflikes_sum = dflikes_sum.sort_values('likes', ascending=False)
# Select the top 10 tags by likes
dflikes_sum= dflikes_sum.nlargest(10, 'likes')


# calculate the mean of likes of each tag value
dflikes_mean = dfwisata.loc[dfwisata['sentiment'] == 'negative'].groupby(["tag"]).mean()
dflikes_mean['likes'] = dflikes_mean.groupby(["tag"]).mean()['likes']
dflikes_mean.drop(['id'], axis=1, inplace=True)
dflikes_mean = dflikes_mean.sort_values('likes', ascending=False)
# Select the top 10 tags by likes
dflikes_mean= dflikes_mean.nlargest(10, 'likes')

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 5))

# Create a bar plot of the total likes
axs[0].bar(dflikes_sum.index, dflikes_sum['likes'], color='red')
axs[0].set_title('Sum of Likes by Tag on negative only sentiment')
axs[0].set_xticklabels(dflikes_sum.index, rotation=90)


# Create a bar plot of the mean of likes
axs[1].bar(dflikes_mean.index, dflikes_mean['likes'], color='red')
axs[1].set_title('Mean of Likes by Tag on negative only sentiment')
axs[1].set_xticklabels(dflikes_mean.index, rotation=90)

# adjust the spacing between the subplots
plt.subplots_adjust(wspace=0.2)

# show the plot
plt.show()
# Out:
# <ipython-input-92-8121a304cb3e>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(dflikes_sum.index, rotation=90)
# <ipython-input-92-8121a304cb3e>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels(dflikes_mean.index, rotation=90)

# %% [markdown]
# > Beberapa analisis dari hasil diatas :
#
#
#
# *   Terlihat bahwa **Artjog** adalah salah satu wisata paling positif di kota jogja dengan menempati **urutan kedua untuk rata-rata likes dari tweets yang bersentimen positif**, dan disisi lain bahkan tidak muncul dalam urutan 10 besar untuk rata-rata likes dari tweets yang bersentimen negatif
# *   **Bangsal kencana** di sisi lain merupakan wisata dengan **tweets negatif dengan jumlah rata-rata likes yang terbanyak**
# *   **Museum Sonoboyo**, **Masjid Gedhe Kauman** dan **Malioboro** merupakan salah satu yang **bervariasi** dimana rata-rata likes pada tweets yang bersentimen positif dan negatif cukup banyak. Tetapi **Museum Sonoboyo** dan **Masjid Gedhe Kauman** masih lebih cenderung **positif** sedangkan **Malioboro** masih lebih cenderung **negatif**
#
#
# *   Daftar tag wisata dengan rata-rata likes yang banyak pada sentimen positif saja : **Gereja Sayidan**, **De Mata Museum**
# *   Daftar tag wisata dengan rata-rata likes yang banyak pada sentimen negatif saja : **Gembira Loka**, **Taman Sari**, **Museum Nasional Yogyakarta**
